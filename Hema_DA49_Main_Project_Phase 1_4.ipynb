# %% [markdown]
# <div style="
#     margin:30px 0 14px 0;
#     padding:15px 20px;
#     background:linear-gradient(90deg,#2563eb 0%,#0f172a 100%);
#     border-radius:12px;
#     color:white;">
#     <h1 style="text-align:center;margin:0;color:white;font-size:30px;">Financial Advisory Clients Data Analysis</h1>
# </div>

# %% [markdown]
# <div style="
#     margin:30px 0 14px 0;
#     padding:15px 20px;
#     background:linear-gradient(90deg,#2563eb 0%,#0f172a 100%);
#     border-radius:12px;
#     color:white;">
#     <h2 style="text-align:center;margin:0;color:white;font-size:20px;">A Data-Driven Analysis of Client Demographics and Financial Characteristics</h2>
# </div>

# %% [markdown]
# <br><b> Submitted By:</b> Hema M Soman
#
# <b> Course:</b> Program In AI Driven Data Analytics
#
# <b> Tools:</b> Python | Pandas | NumPy | Matplotlib | Seaborn | Plotly | Jupyter Notebook

# %% [markdown]
# <div style="background:#f8fafc;border:1px solid #e2e8f0;border-radius:14px;padding:22px;">
# <h2 style="color:#0f172a;margin-top:0;">📑 Project Roadmap</h2>
#
# <h3 style="color:#1d4ed8;">Phase 1 — Project Foundation & Data Understanding</h3>
# <ol style="line-height:1.8;color:#334155;">
# <li>Project Overview</li>
# <li>Project Aim</li>
# <li>Problem Statement</li>
# <li>Dataset Overview</li>
# <li>Dataset Description & Feature Dictionary</li>
# <li>Tools & Libraries</li>
# <li>Data Loading</li>
# <li>Initial Data Understanding</li>
# </ol>
#
# <h3 style="color:#1d4ed8;">Phase 2 — Data Preprocessing</h3>
# <ol start="10" style="line-height:1.8;color:#334155;">
# <li>Data Quality Assessment</li>
# <li>Missing-Value Treatment</li>
# <li>Data Type & Format Correction</li>
# <li>Duplicate Record Validation</li>
# <li>Invalid-Value Validation</li>
# <li>Outlier Detection using IQR</li>
# <li>Feature Engineering</li>
# <li>Final Dataset Information</li>
# </ol>
#
# <h3 style="color:#1d4ed8;">Phase 3 — Exploratory Data Analysis</h3>
# <ol start="18" style="line-height:1.8;color:#334155;">
# <li>Univariate</li>
# <li>Bivariate</li>
# <li>Multivariate</li>
# </ol>
#
# <h3 style="color:#1d4ed8;">Phase 4 — Insight Generation and Report </h3>
# <ol start="21" style="line-height:1.8;color:#334155;">
# <li>Summary Of the Analysis</li>
# <li>Final Recommendations</li>
# </ol>

# %% [markdown]
# <div style="
#     margin:30px 0 14px 0;
#     padding:15px 20px;
#     background:linear-gradient(90deg,#1d4ed8 0%,#0f172a 100%);
#     border-radius:12px;
#     color:white;">
#     <h2 style="margin:0;color:white;font-size:25px;">1. Project Overview</h2>
#     <p style="margin:5px 0 0 0;color:#dbeafe;font-size:14px;">Business context and analytical direction</p>
# </div>

# %% [markdown]
# <h3 style="margin:0 0 8px 0;color:#0f172a;">Why this project matters</h3>
#     The financial advisory services plays a vital role in helping individuals manage their income, savings, investments, debt, and long-term financial goals. Financial advisors collect information about clients financial situations and provide personalized recommendations based on factors such as income, risk tolerance, investment portfolio, and financial objectives. A structured analysis of client data can reveal
# patterns across income, debt, savings, investment portfolios, risk tolerance and satisfaction.
# <br><br>
# This project applies a complete data-analytics workflow to a financial advisory client dataset:
# <b>data understanding → data quality assessment → preprocessing → feature engineering → exploratory analysis → insight generation</b>.
# The goal is to transform raw client records into a reliable analytical foundation for understanding
# financial behaviour and advisory-service experience.

# %% [markdown]
# <div style="
#     margin:30px 0 14px 0;
#     padding:15px 20px;
#     background:linear-gradient(90deg,#1d4ed8 0%,#0f172a 100%);
#     border-radius:12px;
#     color:white;">
#     <h2 style="margin:0;color:white;font-size:25px;">2. Project Aim</h2>
#     <p style="margin:5px 0 0 0;color:#dbeafe;font-size:14px;">A clear, measurable analytical purpose</p>
# </div>

# %% [markdown]
# To systematically analyze the Financial Advisory Clients dataset to understand clients financial behavior, investment patterns, risk preferences, satisfaction levels, to identify the key factors that influence their financial decisions and overall advisory experience, while preparing the data through appropriate cleaning, validation and feature-engineering techniques for reliable exploratory analysis and data-driven insight generation.

# %% [markdown]
# <div style="
#     margin:30px 0 14px 0;
#     padding:15px 20px;
#     background:linear-gradient(90deg,#1d4ed8 0%,#0f172a 100%);
#     border-radius:12px;
#     color:white;">
#     <h2 style="margin:0;color:white;font-size:25px;">3. Problem Statement</h2>
#     <p style="margin:5px 0 0 0;color:#dbeafe;font-size:14px;">From raw client records to reliable analytical insights</p>
# </div>

# %% [markdown]
# <h3>The analytical problem</h3>
#    Financial client datasets can contain missing observations, inconsistent data formats,
#                 unsuitable data types, duplicate records, invalid values and extreme observations.
#                 If these issues are not identified and addressed, data analysis may produce misleading
#                 summaries, relationships or business interpretations.
#                 <br><br>
#                 Therefore, The primary objective of this project is to address these data quality challenges through data cleaning and preprocessing  techniques and then perform exploratory data analysis on the financial advisory client dataset. The analysis aims to identify important patterns and relationships among factors such as income, debt, savings, investments, risk tolerance, financial goals, and client satisfaction, and to generate meaningful insights that can support better financial advisory services and decision-making.</div>

# %% [markdown]
# <div style="
#     margin:30px 0 14px 0;
#     padding:15px 20px;
#     background:linear-gradient(90deg,#1d4ed8 0%,#0f172a 100%);
#     border-radius:12px;
#     color:white;">
#     <h2 style="margin:0;color:white;font-size:25px;">4. Dataset Overview</h2>
#     <p style="margin:5px 0 0 0;color:#dbeafe;font-size:14px;">Scope, source and structure of the analytical dataset</p>
# </div>

# %% [markdown]
# <h3 style="margin-top:0;">📊 Dataset at a Glance</h3>
# <p style="color:#334155;line-height:1.65;">
# The project uses the <b>Financial-Advisory-Clients</b> dataset containing
# <b>5,000 client records and 31 attributes</b>. The variables cover client demographics,
# financial condition, investment behaviour, financial goals, advisory interactions and satisfaction.
# </p>
#
# <table style="width:100%;border-collapse:collapse;margin-top:14px;">
# <tr style="background:#1d4ed8;color:white;">
# <th style="padding:10px;text-align:left;">Item</th><th style="padding:10px;text-align:left;">Details</th>
# </tr>
# <tr><td style="padding:9px;border:1px solid #d1fae5;">Dataset</td><td style="padding:9px;border:1px solid #d1fae5;">Financial-Advisory-Clients</td></tr>
# <tr><td style="padding:9px;border:1px solid #d1fae5;">Records</td><td style="padding:9px;border:1px solid #d1fae5;">5,000</td></tr>
# <tr><td style="padding:9px;border:1px solid #d1fae5;">Original attributes</td><td style="padding:9px;border:1px solid #d1fae5;">31</td></tr>
# <tr><td style="padding:9px;border:1px solid #d1fae5;">Source</td><td style="padding:9px;border:1px solid #d1fae5;">Hugging Face</td></tr>
# <tr><td style="padding:9px;border:1px solid #d1fae5;">Format</td><td style="padding:9px;border:1px solid #d1fae5;">CSV</td></tr>
# <tr><td style="padding:9px;border:1px solid #d1fae5;">Domain</td><td style="padding:9px;border:1px solid #d1fae5;">Finance / Financial Advisory</td></tr>
# <tr><td style="padding:9px;border:1px solid #d1fae5;">Environment</td><td style="padding:9px;border:1px solid #d1fae5;">Python — Jupyter Notebook</td></tr>
# <tr><td style="padding:9px;border:1px solid #d1fae5;">Core libraries</td><td style="padding:9px;border:1px solid #d1fae5;">NumPy, Pandas, Matplotlib, Seaborn, Plotly</td></tr>
# </table>
#
# | No.|Column|Description |
# |---:|---|---|
# | 1 | `client_id` | A unique identifier assigned to each client. It is used to distinguish one client from another. |
# | 2 | `age` | The age of the client in years. |
# | 3 | `employment_status` | Indicates the current employment condition of the client, such as employed, self-employed, unemployed, or retired. |
# | 4 | `marital_status` | Indicates the marital status of the client, such as single, married, or divorced. |
# | 5 | `dependents_count` | The number of people financially dependent on the client. |
# | 6 | `annual_income_usd` | The total income earned by the client in one year, measured in US dollars. |
# | 7 | `credit_score` | A numerical score representing the client's creditworthiness and ability to repay borrowed money. |
# | 8 | `total_debt_usd` | The total amount of debt owed by the client, measured in US dollars. |
# | 9 | `monthly_expenses_usd` | The approximate amount of money the client spends on expenses each month. |
# | 10 | `emergency_fund_months` | The number of months for which the client's emergency savings can cover their regular expenses. |
# | 11 | `investment_portfolio_usd` | The total current value of the client's investments, measured in US dollars. |
# | 12 | `primary_goal` | The main financial objective of the client, such as retirement planning, wealth creation, education, or debt repayment. |
# | 13 | `time_horizon_years` | The number of years within which the client expects to achieve their financial goal. |
# | 14 | `target_amount_usd` | The amount of money the client aims to accumulate or achieve for their financial goal. |
# | 15 | `risk_tolerance_1_10` | A score from 1 to 10 representing how much financial or investment risk the client is willing to accept. |
# | 16 | `preferred_channel` | The client's preferred method of communicating with the financial advisor, such as phone, email, video call, or in-person meetings. |
# | 17 | `checkin_frequency` | Indicates how frequently the client prefers to communicate or have follow-up sessions with the financial advisor. |
# | 18 | `last_session_date` | The date on which the client most recently had a session with the financial advisor. |
# | 19 | `session_duration_min` | The duration of the client's advisory session, measured in minutes. |
# | 20 | `topics_discussed` | The main financial topics discussed between the client and the financial advisor. |
# | 21 | `recommended_products` | The financial products recommended to the client based on their financial situation and requirements. |
# | 22 | `user_satisfaction_1_5` | A rating from 1 to 5 representing the client's satisfaction with the financial advisory service. |
# | 23 | `trust_in_institutions_1_10` | A score from 1 to 10 representing the client's level of trust in financial institutions. |
# | 24 | `debt_income_ratio` | The ratio of the client's total debt to their annual income. It indicates the client's debt burden relative to their income. |
# | 25 | `savings_rate` | The proportion of the client's income that is saved rather than spent. |
# | 26 | `portfolio_income_ratio` | The ratio of the client's investment portfolio value to their annual income. It shows the size of the investment portfolio relative to yearly income. |
# | 27 | `log_income` | A logarithmic transformation of annual income, used to reduce the effect of extreme income values and reduce skewness in the data. |
# | 28 | `log_portfolio` | A logarithmic transformation of the investment portfolio value, used to reduce skewness and the influence of very large portfolio values. |
# | 29 | `age_squared` | The square of the client's age. This is an engineered feature used to capture possible non-linear relationships between age and other variables. |
# | 30 | `income_x_debt` | An interaction feature created by multiplying annual income by total debt. It represents the combined relationship between income and debt. |
# | 31 | `portfolio_x_age` | An interaction feature created by multiplying investment portfolio value by age. It captures the combined effect of age and investment wealth. |

# %% [markdown]
# <div style="
#     margin:30px 0 14px 0;
#     padding:15px 20px;
#     background:linear-gradient(90deg,#1d4ed8 0%,#0f172a 100%);
#     border-radius:12px;
#     color:white;">
#     <h2 style="margin:0;color:white;font-size:25px;">5. Professional Introduction</h2>
#     <p style="margin:5px 0 0 0;color:#dbeafe;font-size:14px;">Project context and analytical workflow</p>
# </div>

# %% [markdown]
# <h3>Introduction</h3>
#     This project presents a structured analysis of financial advisory client data with the
#                 objective of converting raw client records into meaningful, decision-oriented information.
#                 The dataset captures multiple dimensions of a client's financial profile, including
#                 <b>income, expenses, debt, emergency savings, investments, financial goals, risk tolerance,
#                 communication preferences and satisfaction</b>.
#                 <br><br>
#                 The work follows a practical data-analytics lifecycle. First, the dataset is loaded and examined
#                 to understand its structure and quality. Next, missing values, data types, formats, duplicate
#                 records, invalid values and outliers from numerical columns are assessed. Relevant variables are then
#                 transformed or engineered to improve analytical usefulness. Finally, exploratory analysis is
#                 used to identify patterns, relationships and trends that can support better understanding of
#                 client financial behaviour and advisory-service outcomes.

# %% [markdown]
# <div style="
#     margin:30px 0 14px 0;
#     padding:15px 20px;
#     background:linear-gradient(90deg,#1d4ed8 0%,#0f172a 100%);
#     border-radius:12px;
#     color:white;">
#     <h2 style="margin:0;color:white;font-size:25px;">6. Tools & Libraries</h2>
#     <p style="margin:5px 0 0 0;color:#dbeafe;font-size:14px;">Technical environment used for the analysis</p>
# </div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import plotly.graph_objects as go
import plotly.express as px

# %matplotlib inline

# %% [markdown]
# <div style="
#     margin:30px 0 14px 0;
#     padding:15px 20px;
#     background:linear-gradient(90deg,#1d4ed8 0%,#0f172a 100%);
#     border-radius:12px;
#     color:white;">
#     <h2 style="margin:0;color:white;font-size:25px;">7. Data Loading</h2>
#     <p style="margin:5px 0 0 0;color:#dbeafe;font-size:14px;">Importing the financial advisory client records</p>
# </div>

# %%
df=pd.read_csv("financial_advisory_clients.csv")

# %% [markdown]
# <div style="
#     margin:30px 0 14px 0;
#     padding:15px 20px;
#     background:linear-gradient(90deg,#1d4ed8 0%,#0f172a 100%);
#     border-radius:12px;
#     color:white;">
#     <h2 style="margin:0;color:white;font-size:25px;">8. Initial Data Understanding</h2>
#     <p style="margin:5px 0 0 0;color:#dbeafe;font-size:14px;">Establishing the dataset structure before preprocessing</p>
# </div>

# %%
df
# Out:
#      client_id  age employment_status  annual_income_usd marital_status  \
# 0        C0001   23          Salaried       63500.856612        Married
# 1        C0002   63           Retired       59796.942795        Married
# 2        C0003   64          Salaried      202977.754152        Married
# 3        C0004   64           Retired      102286.119426        Married
# 4        C0005   63     Self-Employed      120564.386501        Married
# ...        ...  ...               ...                ...            ...
# 4995     C4996   42          Salaried       90894.139877         Single
# 4996     C4997   43          Salaried       99799.642318         Single
# 4997     C4998   22     Self-Employed      209336.640804        Married
# 4998     C4999   23           Student       13796.144758        Married
# 4999     C5000   24           Student        1808.737608        Married
#
#       dependents_count  credit_score  total_debt_usd  monthly_expenses_usd  \
# ...

# %% [markdown]
# #### Shape of the dataset

# %%
df.shape
# Out:
# (5000, 31)

# %% [markdown]
# #### Top five rows of the dataset

# %%
df.head()
# Out:
#   client_id  age employment_status  annual_income_usd marital_status  \
# 0     C0001   23          Salaried       63500.856612        Married
# 1     C0002   63           Retired       59796.942795        Married
# 2     C0003   64          Salaried      202977.754152        Married
# 3     C0004   64           Retired      102286.119426        Married
# 4     C0005   63     Self-Employed      120564.386501        Married
#
#    dependents_count  credit_score  total_debt_usd  monthly_expenses_usd  \
# 0                 0         412.0    28729.052695           3020.582650
# 1                 2         422.0    16671.005369           2132.882138
# 2                 1         466.0   160395.189390           7169.872744
# 3                 2         429.0    62305.180469           4280.311306
# 4                 2         450.0   155854.785315           4754.005969
#
#    emergency_fund_months  ...  \
# 0                      3  ...
# 1                      4  ...
# ...

# %% [markdown]
# #### Bottom Five Rows of the Dataset

# %%
df.tail()
# Out:
#      client_id  age employment_status  annual_income_usd marital_status  \
# 4995     C4996   42          Salaried       90894.139877         Single
# 4996     C4997   43          Salaried       99799.642318         Single
# 4997     C4998   22     Self-Employed      209336.640804        Married
# 4998     C4999   23           Student       13796.144758        Married
# 4999     C5000   24           Student        1808.737608        Married
#
#       dependents_count  credit_score  total_debt_usd  monthly_expenses_usd  \
# 4995                 0         480.0   333602.479742           4517.776140
# 4996                 0         470.0   251592.509755           5389.824760
# 4997                 0         433.0   413598.079936           7546.046897
# 4998                 0         361.0     5161.908590            675.320275
# 4999                 1         372.0     7036.148349             88.841838
#
#       emergency_fund_months  ...  \
# 4995                      4  ...
# ...

# %% [markdown]
# #### Sample information of the dataset

# %%
df.sample()
# Out:
#      client_id  age employment_status  annual_income_usd marital_status  \
# 1597     C1598   55     Self-Employed      135633.981879        Married
#
#       dependents_count  credit_score  total_debt_usd  monthly_expenses_usd  \
# 1597                 1         480.0   145816.733314           7229.655759
#
#       emergency_fund_months  ...  \
# 1597                      4  ...
#
#                                    recommended_products user_satisfaction_1_5  \
# 1597  index funds;blue-chip stocks;corporate bonds;R...                   2.3
#
#       debt_income_ratio  savings_rate  portfolio_income_ratio  log_income  \
# 1597           1.075067      0.296723                2.794636   11.817723
#
#      log_portfolio age_squared income_x_debt  portfolio_x_age
# 1597     12.845427        3025  1.977770e+10     2.084777e+07
#
# [1 rows x 31 columns]

# %% [markdown]
# #### Dataset Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 31 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   client_id                   5000 non-null   object
#  1   age                         5000 non-null   int64
#  2   employment_status           5000 non-null   object
#  3   annual_income_usd           4900 non-null   float64
#  4   marital_status              5000 non-null   object
#  5   dependents_count            5000 non-null   int64
#  6   credit_score                4900 non-null   float64
#  7   total_debt_usd              5000 non-null   float64
#  8   monthly_expenses_usd        4900 non-null   float64
#  9   emergency_fund_months       5000 non-null   int64
#  10  investment_portfolio_usd    4925 non-null   float64
#  11  primary_goal                5000 non-null   object
#  12  time_horizon_years          5000 non-null   int64
# ...

# %% [markdown]
# #### Dataset Columns

# %%
df.columns
# Out:
# Index(['client_id', 'age', 'employment_status', 'annual_income_usd',
#        'marital_status', 'dependents_count', 'credit_score', 'total_debt_usd',
#        'monthly_expenses_usd', 'emergency_fund_months',
#        'investment_portfolio_usd', 'primary_goal', 'time_horizon_years',
#        'target_amount_usd', 'risk_tolerance_1_10',
#        'trust_in_institutions_1_10', 'preferred_channel', 'checkin_frequency',
#        'last_session_date', 'session_duration_min', 'topics_discussed',
#        'recommended_products', 'user_satisfaction_1_5', 'debt_income_ratio',
#        'savings_rate', 'portfolio_income_ratio', 'log_income', 'log_portfolio',
#        'age_squared', 'income_x_debt', 'portfolio_x_age'],
#       dtype='object')

# %% [markdown]
# #### Datatype of the columns

# %%
df.dtypes
# Out:
# client_id                      object
# age                             int64
# employment_status              object
# annual_income_usd             float64
# marital_status                 object
# dependents_count                int64
# credit_score                  float64
# total_debt_usd                float64
# monthly_expenses_usd          float64
# emergency_fund_months           int64
# investment_portfolio_usd      float64
# primary_goal                   object
# time_horizon_years              int64
# target_amount_usd               int64
# risk_tolerance_1_10           float64
# trust_in_institutions_1_10    float64
# preferred_channel              object
# checkin_frequency              object
# last_session_date              object
# session_duration_min            int64
# topics_discussed               object
# recommended_products           object
# user_satisfaction_1_5         float64
# debt_income_ratio             float64
# savings_rate                  float64
# ...

# %% [markdown]
# #### Summary Statistics

# %%
df.describe()
# Out:
#                age  annual_income_usd  dependents_count  credit_score  \
# count  5000.000000       4.900000e+03       5000.000000   4900.000000
# mean     46.771800       1.090614e+05          0.745000    427.164082
# std      18.196306       9.234339e+04          0.822016     49.590271
# min      18.000000       1.000000e+03          0.000000    300.000000
# 25%      30.000000       3.585834e+04          0.000000    389.000000
# 50%      46.000000       9.041342e+04          1.000000    437.000000
# 75%      61.000000       1.714675e+05          1.000000    466.000000
# max      85.000000       1.346752e+06          3.000000    527.000000
#
#        total_debt_usd  monthly_expenses_usd  emergency_fund_months  \
# count    5.000000e+03           4900.000000            5000.000000
# mean     1.606315e+05           4601.394600               3.365400
# std      1.845821e+05           3673.069449               1.540116
# ...

# %% [markdown]
# <div style="
#     margin:30px 0 14px 0;
#     padding:15px 20px;
#     background:linear-gradient(90deg,#1d4ed8 0%,#0f172a 100%);
#     border-radius:12px;
#     color:white;">
#     <h2 style="margin:0;color:white;font-size:30px;">Phase 2 — Data Preparation & Feature Engineering</h2>
#     <p style="margin:5px 0 0 0;color:#dbeafe;font-size:14px;">Transforming raw records into a consistent analytical dataset</p>
# </div>

# %% [markdown]
# <div style="
#     margin:30px 0 14px 0;
#     padding:15px 20px;
#     background:linear-gradient(90deg,#1d4ed8 0%,#0f172a 100%);
#     border-radius:12px;
#     color:white;">
#     <h2 style="margin:0;color:white;font-size:25px;">1. Data Quality Assessment</h2>
#     <p style="margin:5px 0 0 0;color:#dbeafe;font-size:14px;">Identify missingness and inspect existing data types</p>
# </div>

# %%
summary=pd.DataFrame({
    "Columns":df.columns,
    "Datatype": df.dtypes,
    "Missing percentage":(df.isna().sum()/len(df))*100
})
summary=summary.set_index('Columns')
summary
# Out:
#                            Datatype  Missing percentage
# Columns
# client_id                    object                 0.0
# age                           int64                 0.0
# employment_status            object                 0.0
# annual_income_usd           float64                 2.0
# marital_status               object                 0.0
# dependents_count              int64                 0.0
# credit_score                float64                 2.0
# total_debt_usd              float64                 0.0
# monthly_expenses_usd        float64                 2.0
# emergency_fund_months         int64                 0.0
# investment_portfolio_usd    float64                 1.5
# primary_goal                 object                 0.0
# time_horizon_years            int64                 0.0
# target_amount_usd             int64                 0.0
# risk_tolerance_1_10         float64                 0.0
# trust_in_institutions_1_10  float64                 2.0
# ...

# %% [markdown]
# <div style="
#     background:#ffffff;
#     border:1px solid #e2e8f0;
#     border-left:5px solid #0891b2;
#     border-radius:10px;
#     padding:18px 20px;
#     margin:12px 0;
#     box-shadow:0 3px 12px rgba(15,23,42,0.06);">
#     <h3 style="margin:0 0 8px 0;color:#0f172a;">Missing-Value Profile</h3>
#     <div style="color:#475569;line-height:1.65;">This step identifies columns containing missing observations before imputation.
#              The missing value treatment should consider the nature of each variable: central-tendency
#              imputation can be appropriate for numerical measures, while median imputation is often
#              more suitable if it contains outliers.Also categorical columns can be immuted using the mode and missing values in the derived columns were handled using the formula used to derive the column values. </div>
# </div>

# %% [markdown]
# <h4 style="margin:0 0 8px 0;color:#0f172a;">Missing-Value Identification</h4>

# %%
miss_v=df.isnull().sum()
missing_values=miss_v[miss_v>0]
print(missing_values)
# Out:
# annual_income_usd             100
# credit_score                  100
# monthly_expenses_usd          100
# investment_portfolio_usd       75
# trust_in_institutions_1_10    100
# user_satisfaction_1_5          75
# log_income                    100
# income_x_debt                 100
# dtype: int64

# %% [markdown]
#  <h4 style="margin:0 0 8px 0;color:#0f172a;">Missing-Value Filling Using Immutation </h3>

# %%
mean_cols=["credit_score","trust_in_institutions_1_10","user_satisfaction_1_5"]
df[mean_cols]=df[mean_cols].fillna(df[mean_cols].mean())
df["monthly_expenses_usd"]=df["monthly_expenses_usd"].fillna(df["monthly_expenses_usd"].median())
df["annual_income_usd"]=df["annual_income_usd"].fillna(df["annual_income_usd"].median())
#df["investment_portfolio_usd"]=df["investment_portfolio_usd"].fillna(df["investment_portfolio_usd"].median())
df["investment_portfolio_usd"]=df["investment_portfolio_usd"].fillna(0)

df['log_income']=df['log_income'].fillna(np.log(df['annual_income_usd']))
#the income_x_debt missing values filled using annual_income_usd * total_debt_usd
df['income_x_debt']=df['income_x_debt'].fillna(df['annual_income_usd']*df['total_debt_usd'])
print("Number of columns having missing values:")
df.isnull().sum()
# Out:
# Number of columns having missing values:
# client_id                     0
# age                           0
# employment_status             0
# annual_income_usd             0
# marital_status                0
# dependents_count              0
# credit_score                  0
# total_debt_usd                0
# monthly_expenses_usd          0
# emergency_fund_months         0
# investment_portfolio_usd      0
# primary_goal                  0
# time_horizon_years            0
# target_amount_usd             0
# risk_tolerance_1_10           0
# trust_in_institutions_1_10    0
# preferred_channel             0
# checkin_frequency             0
# last_session_date             0
# session_duration_min          0
# topics_discussed              0
# recommended_products          0
# user_satisfaction_1_5         0
# debt_income_ratio             0
# savings_rate                  0
# portfolio_income_ratio        0
# log_income                    0
# log_portfolio                 0
# ...

# %% [markdown]
# <div style="
#     background:#ffffff;
#     border:1px solid #e2e8f0;
#     border-left:5px solid #0891b2;
#     border-radius:10px;
#     padding:18px 20px;
#     margin:12px 0;
#     box-shadow:0 3px 12px rgba(15,23,42,0.06);">
#     <h3 style="margin:0 0 8px 0;color:#0f172a;">Data Validation After Immutation</h3>
#     <div style="color:#475569;line-height:1.65;">After missing-value treatment, summary statistics are reviewed again to confirm that
#              numerical columns are populated and that the overall distribution remains interpretable.
#              This provides a checkpoint before subsequent validation and feature engineering.</div>
# </div>

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', '{:.2f}'.format)
df.describe()
# Out:
#           age  annual_income_usd  dependents_count  credit_score  \
# count 5000.00            5000.00           5000.00       5000.00
# mean    46.77          108688.41              0.74        427.16
# std     18.20           91452.38              0.82         49.09
# min     18.00            1000.00              0.00        300.00
# 25%     30.00           37906.01              0.00        390.00
# 50%     46.00           90413.42              1.00        435.50
# 75%     61.00          169437.01              1.00        465.00
# max     85.00         1346752.46              3.00        527.00
#
#        total_debt_usd  monthly_expenses_usd  emergency_fund_months  \
# count         5000.00               5000.00                5000.00
# mean        160631.47               4586.57                   3.37
# std         184582.12               3637.63                   1.54
# min              0.00                 33.59                   0.00
# ...

# %% [markdown]
# <div style="
#     margin:30px 0 14px 0;
#     padding:15px 20px;
#     background:linear-gradient(90deg,#2563eb 0%,#0f172a 100%);
#     border-radius:12px;
#     color:white;">
#     <h2 style="margin:0;color:white;font-size:25px;">2. Data Type & Format Correction</h2>
#     <p style="margin:5px 0 0 0;color:#dbeafe;font-size:14px;">Make each field suitable for reliable analysis</p>
# </div>

# %%
df['last_session_date']=pd.to_datetime(df['last_session_date'])
df['credit_score'] = df['credit_score'].round().astype(int)

money_cols=["annual_income_usd","total_debt_usd","monthly_expenses_usd","investment_portfolio_usd","target_amount_usd","risk_tolerance_1_10",
            "user_satisfaction_1_5","log_income","log_portfolio","income_x_debt","portfolio_x_age"]
ratio_cols=["debt_income_ratio","savings_rate","portfolio_income_ratio"]

for col in money_cols:
    df[col]=df[col].round(2)
for col in ratio_cols:
    df[col]=df[col].round(4)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 31 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   client_id                   5000 non-null   object
#  1   age                         5000 non-null   int64
#  2   employment_status           5000 non-null   object
#  3   annual_income_usd           5000 non-null   float64
#  4   marital_status              5000 non-null   object
#  5   dependents_count            5000 non-null   int64
#  6   credit_score                5000 non-null   int64
#  7   total_debt_usd              5000 non-null   float64
#  8   monthly_expenses_usd        5000 non-null   float64
#  9   emergency_fund_months       5000 non-null   int64
#  10  investment_portfolio_usd    5000 non-null   float64
#  11  primary_goal                5000 non-null   object
#  12  time_horizon_years          5000 non-null   int64
# ...

# %% [markdown]
# <div style="
#     background:#ffffff;
#     border:1px solid #e2e8f0;
#     border-left:5px solid #7c3aed;
#     border-radius:10px;
#     padding:18px 20px;
#     margin:12px 0;
#     box-shadow:0 3px 12px rgba(15,23,42,0.06);">
#     <h3 style="margin:0 0 8px 0;color:#0f172a;">Categorical Format Standardisation</h3>
#     <div style="color:#475569;line-height:1.65;">Column labels are standardised for consistency and selected categorical fields are inspected
#              through their unique values. This helps identify unexpected category variations and makes
#              downstream grouping and analysis more reliable.</div>
# </div>

# %%
df.columns=df.columns.str.strip().str.title()

categorical_cols=['Employment_Status','Marital_Status','Primary_Goal','Preferred_Channel','Checkin_Frequency']
print(categorical_cols)

for col in categorical_cols:
    print("\n", "="*50)
    print(col)
    print(df[col].unique())
# Out:
# ['Employment_Status', 'Marital_Status', 'Primary_Goal', 'Preferred_Channel', 'Checkin_Frequency']
#
# ...
# Employment_Status
# ['Salaried' 'Retired' 'Self-Employed' 'Student' 'Unemployed']
#
# ...
# Marital_Status
# ['Married' 'Single' 'Divorced' 'Widowed']
#
# ...
# Primary_Goal
# ['Emergency Fund' 'Retirement' 'Wealth Accumulation' 'Healthcare'
#  'Business Investment' 'Estate Planning' 'Travel' 'Home Purchase'
#  'Debt Reduction' 'Education']
#
# ...
# Preferred_Channel
# ['App' 'Email' 'Phone' 'Chat' 'In-Person']
#
# ...
# Checkin_Frequency
# ['Annual' 'Biannual' 'Quarterly' 'Monthly' 'Ad-hoc']

# %% [markdown]
# <div style="
#     margin:30px 0 14px 0;
#     padding:15px 20px;
#     background:linear-gradient(90deg,#2563eb 0%,#0f172a 100%);
#     border-radius:12px;
#     color:white;">
#     <h2 style="margin:0;color:white;font-size:25px;">3. Duplicate Record Validation</h2>
#     <p style="margin:5px 0 0 0;color:#dbeafe;font-size:14px;">Confirm that repeated client records are not distorting the analysis</p>
# </div>

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df=df.drop_duplicates()
df.shape
# Out:
# (5000, 31)

# %%
if df.duplicated().sum()==0:
    print("No duplicate records found")
# Out:
# No duplicate records found

# %% [markdown]
# <div style="
#     margin:30px 0 14px 0;
#     padding:15px 20px;
#     background:linear-gradient(90deg,#2563eb 0%,#0f172a 100%);
#     border-radius:12px;
#     color:white;">
#     <h2 style="margin:0;color:white;font-size:25px;">4. Invalid Value Validation</h2>
#     <p style="margin:5px 0 0 0;color:#dbeafe;font-size:14px;">Check whether numerical fields contain logically problematic values</p>
# </div>

# %%
numerical_cols=df.select_dtypes(include="number").columns
#print(numerical_cols)
(df[numerical_cols]<0).sum()
# Out:
# Age                              0
# Annual_Income_Usd                0
# Dependents_Count                 0
# Credit_Score                     0
# Total_Debt_Usd                   0
# Monthly_Expenses_Usd             0
# Emergency_Fund_Months            0
# Investment_Portfolio_Usd         0
# Time_Horizon_Years               0
# Target_Amount_Usd                0
# Risk_Tolerance_1_10              0
# Trust_In_Institutions_1_10       0
# Session_Duration_Min             0
# User_Satisfaction_1_5            0
# Debt_Income_Ratio                0
# Savings_Rate                  1682
# Portfolio_Income_Ratio           0
# Log_Income                       0
# Log_Portfolio                    0
# Age_Squared                      0
# Income_X_Debt                    0
# Portfolio_X_Age                  0
# dtype: int64

# %% [markdown]
# <div style="
#     background:#ffffff;
#     border:1px solid #e2e8f0;
#     border-left:5px solid #7c3aed;
#     border-radius:10px;
#     padding:18px 20px;
#     margin:12px 0;
#     box-shadow:0 3px 12px rgba(15,23,42,0.06);">
#     <h3 style="margin:0 0 8px 0;color:#0f172a;">Invalid Column Removal</h3>
#     <div style="color:#475569;line-height:1.65;">A negative Savings Rate simply means a client's Monthly_Expenses were higher than their Income for that period. They were spending more than they earned (running a deficit, relying on debt/credit, etc.). This is not  an invalid data and it is a real, meaningful financial situation.</div></div>

# %% [markdown]
# <div style="
#     margin:30px 0 14px 0;
#     padding:15px 20px;
#     background:linear-gradient(90deg,#2563eb 0%,#0f172a 100%);
#     border-radius:12px;
#     color:white;">
#     <h2 style="margin:0;color:white;font-size:25px;">5. Outlier Detection Using - IQR Method</h2>
#     <p style="margin:5px 0 0 0;color:#dbeafe;font-size:14px;">Identify unusual high or low numerical observations without automatically deleting them</p>
# </div>

# %%
df.describe()
# Out:
#           Age  Annual_Income_Usd  Dependents_Count  Credit_Score  \
# count 5000.00            5000.00           5000.00       5000.00
# mean    46.77          108688.41              0.74        427.16
# min     18.00            1000.00              0.00        300.00
# 25%     30.00           37906.01              0.00        390.00
# 50%     46.00           90413.42              1.00        435.50
# 75%     61.00          169437.01              1.00        465.00
# max     85.00         1346752.46              3.00        527.00
# std     18.20           91452.38              0.82         49.09
#
#        Total_Debt_Usd  Monthly_Expenses_Usd  Emergency_Fund_Months  \
# count         5000.00               5000.00                5000.00
# mean        160631.47               4586.57                   3.37
# min              0.00                 33.59                   0.00
# 25%          28413.06               1541.09                   2.00
# ...

# %%
outlier_cols = [
    'Emergency_Fund_Months',
    'Investment_Portfolio_Usd',
    'Time_Horizon_Years',
    'Risk_Tolerance_1_10',
    'Session_Duration_Min',
    'User_Satisfaction_1_5'
]
for col in outlier_cols:
    Q1=df[col].quantile(0.25)
    Q3=df[col].quantile(0.75)

    IQR=Q3-Q1

    lower_limit=Q1-1.5*IQR
    upper_limit=Q3+1.5*IQR

    outliers=df[(df[col]<lower_limit) | (df[col]>upper_limit)]

    print(col,":",len(outliers),"outliers")
    #print(outliers[[col]].head(10))
# Out:
# Emergency_Fund_Months : 54 outliers
# Investment_Portfolio_Usd : 176 outliers
# Time_Horizon_Years : 423 outliers
# Risk_Tolerance_1_10 : 10 outliers
# Session_Duration_Min : 16 outliers
# User_Satisfaction_1_5 : 37 outliers

# %% [markdown]
# <div style="
#     background:#ffffff;
#     border:1px solid #e2e8f0;
#     border-left:5px solid #7c3aed;
#     border-radius:10px;
#     padding:18px 20px;
#     margin:12px 0;
#     box-shadow:0 3px 12px rgba(15,23,42,0.06);">
#     <h3 style="margin:0 0 8px 0;color:#0f172a;">Outlier Removal</h3>
#     <div style="color:#475569;line-height:1.65;">Outliers were identified using the IQR method. However, IQR-based outliers were not automatically considered errors. Each variable was reviewed in the context of financial advisory data, and observations were retained to preserve genuine client-level variation.
# <br/>
# <b>Emergency_Fund_Months (54):</b> Extreme values may reflect differences in clients’ financial preparedness and emergency-fund strategies as each client holds different financial position.
# <br/><b>Investment_Portfolio_Usd (176):</b> High values may represent clients with substantial investment holdings. Since these values can be financially realistic, they were retained.
# <br/><b>Time_Horizon_Years (423):</b> The relatively high number of statistical outliers may reflect genuine differences in clients’ financial goals and planning periods. There are possibilities of clients having longer period of goal achievement as there is not a fixed time period is not mentioned. These observations were retained where values were plausible.
# <br/><b>Risk_Tolerance_1_10 (10):</b> Although some values were identified as IQR outliers, they remained within the valid 1–10 scale. Therefore, they were retained as valid client preferences.
# <br/><b>Session_Duration_Min (16):</b> Variation in session duration may result from differences in client requirements and discussion complexity.
# <br/><b>User_Satisfaction_1_5 (37):</b> Extreme observations remained within the valid 1–5 rating scale and may represent genuine differences in client experience. Therefore, they were retained.
#
# <b>Overall Decision: No statistical outliers were removed here.</b></div>
# </div>

# %% [markdown]
# <div style="
#     margin:30px 0 14px 0;
#     padding:15px 20px;
#     background:linear-gradient(90deg,#2563eb 0%,#0f172a 100%);
#     border-radius:12px;
#     color:white;">
#     <h2 style="margin:0;color:white;font-size:25px;">6. Feature Engineering</h2>
#     <p style="margin:5px 0 0 0;color:#dbeafe;font-size:14px;">Create analysis- relevant variables from existing client attributes</p>
# </div>

# %% [markdown]
# <table style="width:100%;border-collapse:collapse;margin-top:14px;">
# <tr style="background:#1d4ed8;color:white;">
# <th style="padding:10px;text-align:left;">Enginerred Feature</th><th style="padding:10px;text-align:left;">Purpose</th>
# </tr>
# <tr><td style="padding:9px;border:1px solid #d1fae5;">Monthly_Income_Usd</td><td style="padding:9px;border:1px solid #d1fae5;">Created column for monthly income from annual income column</td></tr>
# <tr><td style="padding:9px;border:1px solid #d1fae5;">Disposable_Income_Usd</td><td style="padding:9px;border:1px solid #d1fae5;">Column to display howmuch income remains after expenses monthly</td></tr>
# <tr><td style="padding:9px;border:1px solid #d1fae5;">Expense_Income_Ratio</td><td style="padding:9px;border:1px solid #d1fae5;">Ratio of expense and income calculated from monthly expenses and income</td></tr>
# <tr><td style="padding:9px;border:1px solid #d1fae5;">Emergency_Fund_Amount</td><td style="padding:9px;border:1px solid #d1fae5;">Empergency fund amount calculated by using monthly expenses and emergency fund months</td></tr>
# <tr><td style="padding:9px;border:1px solid #d1fae5;">Age_Group</td><td style="padding:9px;border:1px solid #d1fae5;">Groups clients into age-based categories</td></tr>
# <tr><td style="padding:9px;border:1px solid #d1fae5;">Risk_Category</td><td style="padding:9px;border:1px solid #d1fae5;">Groups clients risk levels into risk-based categories</td></tr>
# <tr><td style="padding:9px;border:1px solid #d1fae5;">Total_NumberOfTopics_Discussed</td><td style="padding:9px;border:1px solid #d1fae5;">Count of topics discussed by each client</td></tr>
# </table>

# %%
# Monthly expenses already present, so monthly income also created from annual income
df["Monthly_Income_Usd"]=(df["Annual_Income_Usd"]/12).round(2)

# Calculate howmuch income remains after expenses monthly
df['Disposable_Income_Usd'] = (df['Monthly_Income_Usd'] -df['Monthly_Expenses_Usd']).round(2)

# Emergency fund month already present,so empergency fund per month calculated by using monthly expenses and emergency fund months
df["Emergency_Fund_Amount"]= (df["Monthly_Expenses_Usd"]*df["Emergency_Fund_Months"]).round(2)

# Age group
df['Age_Group']=pd.cut(df['Age'],bins=[0,30,45,60,100],labels=['Young','Middle-Aged','Senior','Older'])

# Risk category
df['Risk_Category'] = pd.cut(df['Risk_Tolerance_1_10'],bins=[0, 3, 7, 10],labels=['Low Risk', 'Moderate Risk', 'High Risk'])

# Column to get the number of topics discussed by each client
df["Total_NumberOfTopics_Discussed"]=df['Topics_Discussed'].str.split(";").str.len()

df.sample(10)
# Out:
#      Client_Id  Age Employment_Status  Annual_Income_Usd Marital_Status  \
# 1024     C1025   51          Salaried          399504.35        Married
# 1196     C1197   52     Self-Employed          304080.45        Married
# 516      C0517   51     Self-Employed           98561.67         Single
# 957      C0958   61           Retired           46927.01        Married
# 33       C0034   51     Self-Employed          297076.16        Married
# 4757     C4758   61           Retired           63405.76         Single
# 3506     C3507   25          Salaried          116260.90        Married
# 2917     C2918   58          Salaried          180141.62        Married
# 90       C0091   58          Salaried           91874.31         Single
# 1500     C1501   19           Student           14674.44         Single
#
#       Dependents_Count  Credit_Score  Total_Debt_Usd  Monthly_Expenses_Usd  \
# 1024                 0           475       284508.76              17285.99
# ...

# %% [markdown]
# <div style="
#     margin:30px 0 14px 0;
#     padding:15px 20px;
#     background:linear-gradient(90deg,#2563eb 0%,#0f172a 100%);
#     border-radius:12px;
#     color:white;">
#     <h2 style="margin:0;color:white;font-size:25px;">Final Dataset Information</h2>
#     </div>

# %%
df.to_csv("Cleaned_financial_advisory_clients_dataset.csv",index=False)

# %% [markdown]
# <div style="
#     margin:30px 0 14px 0;
#     padding:15px 20px;
#     background:linear-gradient(90deg,#2563eb 0%,#0f172a 100%);
#     border-radius:12px;
#     color:white;">
#     <h2 style="margin:0;color:white;font-size:25px;">Phase 1 & Phase 2 Conclusion</h2>
#     </div>

# %% [markdown]
# The original dataset contained 5,000 client records and 31 attributes, covering variables such as age, employment status, income, debt, monthly expenses, emergency-fund coverage, investment portfolio, financial goals, risk tolerance, communication preferences and satisfaction.
#
# The analysis followed a structured data-analytics workflow consisting of data understanding, data-quality assessment, preprocessing, feature engineering and exploratory data analysis. Missing values, data types, duplicate records, invalid values and numerical outliers were assessed before the dataset was used for EDA.
#
# Missing values were treated according to the nature of the variables, including median-based treatment for relevant numerical variables and formula-based treatment for derived variables. Duplicate records were also removed during preprocessing.
# The analysis also identified a large number of IQR-based outliers in variables such as emergency-fund months, investment portfolio, time horizon, risk tolerance, session duration and satisfaction. Rather than automatically deleting all extreme observations, the analysis retained legitimate financial extremes because substantial differences in income, debt and wealth can naturally occur between clients.
# One important preprocessing observation was that Savings_Rate contained many negative values, indicating situations where expenses exceeded income. Since this variable is a real and meaniful data, it is not dropped and used in the further analysis to detect the cause of this negative values.
#
# After preprocessing, the dataset contained 5000 records and 38 variables, providing the analytical dataset used for the main EDA.

# %% [markdown]
# <div style="
#     margin:30px 0 14px 0;
#     padding:15px 20px;
#     background:linear-gradient(90deg,#2563eb 0%,#0f172a 100%);
#     border-radius:12px;
#     color:white;">
#     <h2 style="margin:0;color:white;font-size:25px;">Phase 3 - Exploratory Data Analysis</h2>
#     <p style="margin:5px 0 0 0;color:#dbeafe;font-size:14px;">Descriptive and exploratory analysis to uncover patterns and trends</p>
#     </div>

# %% [markdown]
# <div style="
#     margin:30px 0 14px 0;
#     padding:15px 20px;
#     background:linear-gradient(90deg,#2563eb 0%,#0f172a 100%);
#     border-radius:12px;
#     color:white;">
#     <h2 style="margin:0;color:white;font-size:18px;">Univariate Analysis</h2>
#     </div>

# %% [markdown]
#   <div style="
#     margin:30px 0 20px 0;
#     padding:0 0 12px 0;
#     border-bottom:2px solid #2563eb;">
#   <h3 style="
#         margin:0;
#         color:#0f172a;
#         font-size:15px;
#         font-weight:700;
#         line-height:1.5;
#     ">
#         📊 Question 1: What are the most common categories among clients in terms of age group, primary financial goal, employment status, preferred communication channel, and check-in frequency?
#     </h3>
#
# </div>

# %%
cols=['Age_Group','Primary_Goal','Employment_Status','Preferred_Channel','Checkin_Frequency']
for col in cols:
    print('='*50)
    print(df[col].value_counts())
# Out:
# ...
# Age_Group
# Older          1352
# Young          1266
# Senior         1213
# Middle-Aged    1169
# Name: count, dtype: int64
# ...
# Primary_Goal
# Retirement             1481
# Healthcare              542
# Home Purchase           528
# Wealth Accumulation     449
# Estate Planning         436
# Education               417
# Travel                  394
# Emergency Fund          305
# Debt Reduction          260
# Business Investment     188
# Name: count, dtype: int64
# ...
# Employment_Status
# Salaried         1976
# Retired          1010
# Self-Employed     986
# Student           527
# Unemployed        501
# Name: count, dtype: int64
# ...
# Preferred_Channel
# Email        1509
# App          1318
# Phone        1038
# In-Person     809
# Chat          326
# Name: count, dtype: int64
# ...
# Checkin_Frequency
# Quarterly    1715
# Biannual     1146
# Monthly       976
# Annual        895
# Ad-hoc        268
# Name: count, dtype: int64

# %% [markdown]
# <div style="background:#fdf2f8;padding:16px;border-radius:10px;border:1px solid #fbcfe8;">
# <b style="color:#be185d;font-size:15px;">💡 Insight</b><br>
# <span style="color:#475569;"><b>*</b>  The univariate analysis of categorical variables shows that the Older age group has the highest number of clients (1,352), followed by Young (1,266), Senior (1,213), and Middle-Aged (1169) clients. In terms of financial objectives, Retirement is the most common primary financial goal (1,481 clients) followed by Healthcare (542 clients), whereas Business Investment is the least common (188 clients).
#  <br/><b>*</b> Salaried clients are the largest group (1,976), followed by Retired (1,010),
# Self-Employed (986), Student (527), and Unemployed (501). Salaried and Retired clients together
# make up roughly 60% of the client base.
#   <br/><b>*</b>  Regarding communication preferences, Email is the most preferred channel (1,509 clients), followed by App (1,318), Phone (1038) and In-person (809), while Chat is the least preferred (326). <br/><b>*</b>For client engagement, Quarterly check-ins are the most common (1,715 clients), followed by Biannual (1,146) and Monthly (976), whereas Ad-hoc check-ins are the least common (268).<br/> <b>* </b> Overall, the analysis indicates that the dataset contains a relatively larger proportion of Older and Senior clients, with Retirement being the dominant financial goal, Email being the most preferred communication channel, and Quarterly being the most common check-in frequency.</span>
# </div>

# %% [markdown]
# <div style="
#     margin:30px 0 20px 0;
#     padding:0 0 12px 0;
#     border-bottom:2px solid #2563eb;">
#   <h3 style="
#         margin:0;
#         color:#0f172a;
#         font-size:15px;
#         font-weight:700;
#         line-height:1.5;
#     ">
#         📊 Question 2: What is the average age of clients, and how spread out are the ages?
#     </h3>
#
# </div>

# %%
df['Age'].describe().round(1)
# Out:
# count   5000.00
# mean      46.80
# std       18.20
# min       18.00
# 25%       30.00
# 50%       46.00
# 75%       61.00
# max       85.00
# Name: Age, dtype: float64

# %% [markdown]
# <div style="background:#fdf2f8;padding:16px;border-radius:10px;border:1px solid #fbcfe8;">
# <b style="color:#be185d;font-size:15px;">💡 Insight</b><br>
# <span style="color:#475569;"><b>*</b> The average client age is about 46.8 years (median 46), with a standard deviation
# of 18.2 years. Ages range from 18 to 85, and the middle 50% of clients (25th–75th percentile) fall
# between 30 and 61 years — so the client base spans young adults through retirees fairly evenly, without
# a single dominant age band. </span></div>

# %% [markdown]
# <div style="
#     margin:30px 0 20px 0;
#     padding:0 0 12px 0;
#     border-bottom:2px solid #2563eb;">
#   <h3 style="
#         margin:0;
#         color:#0f172a;
#         font-size:15px;
#         font-weight:700;
#         line-height:1.5;
#     ">
#         📊 Question 3: What is the basic statistical summary of client satisfaction??
#     </h3>
#
# </div>

# %%
df['User_Satisfaction_1_5'].describe()
# Out:
# count   5000.00
# mean       2.72
# std        0.52
# min        1.00
# 25%        2.40
# 50%        2.70
# 75%        3.10
# max        4.60
# Name: User_Satisfaction_1_5, dtype: float64

# %% [markdown]
# <div style="background:#fdf2f8;padding:16px;border-radius:10px;border:1px solid #fbcfe8;">
# <b style="color:#be185d;font-size:15px;">💡 Insight</b><br>
# <span style="color:#475569;">The clients have an average satisfaction score of 2.72 out of 5. The median score is 2.70, indicating
# that the typical client has a moderate level of satisfaction. The middle 50% of clients have satisfaction scores between 2.40 and 3.10, while the
# overall scores range from 1.00 to 4.60. This suggests that client satisfaction is generally moderate rather than highly positive, highlighting
# potential opportunities to improve the overall client experience.
# </span>
# </div>

# %% [markdown]
# <div style="
#     margin:30px 0 20px 0;
#     padding:0 0 12px 0;
#     border-bottom:2px solid #2563eb;">
#   <h3 style="
#         margin:0;
#         color:#0f172a;
#         font-size:15px;
#         font-weight:700;
#         line-height:1.5;
#     ">
#         📊 Question 4: What does the typical client's annual income look like, and how much does it vary?
#     </h3>
#
# </div>

# %%
print(df['Annual_Income_Usd'].describe())
# Out:
# count      5000.00
# mean     108688.41
# std       91452.38
# min        1000.00
# 25%       37906.01
# 50%       90413.42
# 75%      169437.01
# max     1346752.46
# Name: Annual_Income_Usd, dtype: float64

# %% [markdown]
# <div style="background:#fdf2f8;padding:16px;border-radius:10px;border:1px solid #fbcfe8;">
# <b style="color:#be185d;font-size:15px;">💡 Insight</b><br>
# <span style="color:#475569;">The average annual income of clients is 10,8688.41 usd, while the median income is 90,413.42 usd, indicating that higher-income clients are likely pulling the average upward. The income ranges widely from 1,000 usd to 1,346,752.46 usd, showing substantial variation in clients’ financial backgrounds.
#     Additionally, 50% of clients have annual incomes between 37,906.01 usd and 169,437.01 usd, depicts a diverse income distribution.
# </span>
# </div>

# %% [markdown]
# <div style="
#     margin:30px 0 20px 0;
#     padding:0 0 12px 0;
#     border-bottom:2px solid #2563eb;">
#   <h3 style="
#         margin:0;
#         color:#0f172a;
#         font-size:15px;
#         font-weight:700;
#         line-height:1.5;
#     ">
#         📊 Question 5: Which client has the highest investment and the highest debt amount?
#     </h3>
#
# </div>

# %%
cols=['Client_Id','Age','Employment_Status','Marital_Status','Dependents_Count',
              'Total_Debt_Usd','Monthly_Expenses_Usd','Investment_Portfolio_Usd']

# max_investment=df.iloc[df['Investment_Portfolio_Usd'].argmax()]
# hightest_debt=df.iloc[df['Total_Debt_Usd'].argmax()]
# print(max_investment[cols])
# print(hightest_debt[cols])
top_5_investment=df.nlargest(5,'Investment_Portfolio_Usd')
print('\n','='*50)
print("Top Five Clients with higher Portfolio Investment")
display(top_5_investment[cols])
top_5_debt=df.nlargest(5,'Total_Debt_Usd')
print('\n','='*50)
print("Top Five Clients with higher Total Debt Amount")
display(top_5_debt[cols])
# Out:
# ...
# Top Five Clients with higher Portfolio Investment
#      Client_Id  Age Employment_Status Marital_Status  Dependents_Count  \
# 486      C0487   63          Salaried         Single                 0
# 1001     C1002   61     Self-Employed       Divorced                 1
# 2451     C2452   58     Self-Employed        Married                 1
# 2377     C2378   60     Self-Employed         Single                 2
# 926      C0927   60          Salaried        Married                 1
#
#       Total_Debt_Usd  Monthly_Expenses_Usd  Investment_Portfolio_Usd
# 486        140861.25               9561.80                3816736.64
# 1001       107318.50               6773.80                3381074.92
# 2451       110150.46               9227.46                3327801.49
# 2377        85823.85               6390.27                3304565.55
# 926        241635.31               8989.94                3293474.93
# ...
# Top Five Clients with higher Total Debt Amount
# ...

# %% [markdown]
# <div style="background:#fdf2f8;padding:16px;border-radius:10px;border:1px solid #fbcfe8;">
# <b style="color:#be185d;font-size:15px;">💡 Insight</b><br>
# <span style="color:#475569;"><b>* </b> The top 5 clients with the highest investment portfolios are C0487, C1002, C2452, C2378, and C0927, with investments ranging from 3.29 million usd to 3.81 million usd. These clients are between 58 and 63 years old, indicating that the highest investment portfolios in this dataset are concentrated among relatively older clients.
# <br/>
#     <br/>
#                             <b>* </b> The top 5 clients with the highest debt are C0406, C0644, C0180, C3682, and C4902, with C0406 having the highest debt ranging from 1.22 million usd to 1 million usd. These clients are between 30 and 46 years old, indicating that the highest debt levels in this dataset are concentrated among relatively younger clients.
# </span>
# </div>

# %% [markdown]
# <div style="
#     margin:30px 0 20px 0;
#     padding:0 0 12px 0;
#     border-bottom:2px solid #2563eb;">
#   <h3 style="
#         margin:0;
#         color:#0f172a;
#         font-size:15px;
#         font-weight:700;
#         line-height:1.5;
#     ">
#         📊 Question 6: What are the descriptive statistics of Annual Income, Total Debt, Investment and what does its skewness and kurtosis indicate about the distribution?
#     </h3>
#
# </div>

# %%
cols=['Annual_Income_Usd','Total_Debt_Usd','Investment_Portfolio_Usd']
for col in cols:
    print('\n','='*50)
    print("Summary Statistics is:")
    print(df[col].describe()) 
    print('-'*50)
    print("Measure of symmetry is:")
    print(df[col].skew())
    print("Measure of peakedness is:")
    print(df[col].kurt())
# Out:
# ...
# Summary Statistics is:
# count      5000.00
# mean     108688.41
# std       91452.38
# min        1000.00
# 25%       37906.01
# 50%       90413.42
# 75%      169437.01
# max     1346752.46
# Name: Annual_Income_Usd, dtype: float64
# --------------------------------------------------
# Measure of symmetry is:
# 1.7228108213222566
# Measure of peakedness is:
# 10.360438875715243
#
# ...
# Summary Statistics is:
# count      5000.00
# mean     160631.47
# std      184582.12
# min           0.00
# 25%       28413.06
# 50%       95245.65
# 75%      226747.74
# max     1217457.56
# Name: Total_Debt_Usd, dtype: float64
# --------------------------------------------------
# Measure of symmetry is:
# 1.8680946091286244
# Measure of peakedness is:
# 3.7840377522791657
#
# ...
# Summary Statistics is:
# count      5000.00
# mean     293900.90
# std      347801.34
# min           0.00
# 25%       36615.79
# 50%      191096.61
# 75%      437858.23
# max     3816736.64
# ...

# %% [markdown]
# <div style="background:#fdf2f8;padding:16px;border-radius:10px;border:1px solid #fbcfe8;">
# <b style="color:#be185d;font-size:15px;">💡 Insight</b><br>
# <span style="color:#475569;"><b>* </b> All three financial variables exhibit positive skewness, indicating that their distributions are not symmetric and are influenced by a relatively small number of customers with exceptionally high values. <br/><b>* </b> Investment Portfolio has the highest skewness (2.74) and peakedness (13.84), making it the most heavily skewed and extreme variable. <br/><b>* </b>Annual Income also shows substantial peakedness (10.36), suggesting the presence of high-income clients. <br/><b>* </b> Total Debt is strongly right-skewed (1.86), indicating that a small proportion of customers have disproportionately high debt levels.
#     <br/><b>* </b> The skewness value of 1.72 indicates a positively skewed (right-skewed) distribution, meaning that while most individuals have relatively lower or moderate incomes, a smaller number of individuals earn exceptionally high incomes.<br/><b>* </b> These high-income values pull the mean above the median. Therefore, the median may be a more representative measure of typical income than the mean.</span>
# </div>

# %% [markdown]
# <div style="
#     margin:30px 0 14px 0;
#     padding:15px 20px;
#     background:linear-gradient(90deg,#2563eb 0%,#0f172a 100%);
#     border-radius:12px;
#     color:white;">
#     <h2 style="margin:0;color:white;font-size:18px;">Bivariate Analysis</h2>
#     </div>

# %% [markdown]
# <div style="
#     margin:30px 0 20px 0;
#     padding:0 0 12px 0;
#     border-bottom:2px solid #2563eb;">
#   <h3 style="
#         margin:0;
#         color:#0f172a;
#         font-size:15px;
#         font-weight:700;
#         line-height:1.5;
#     ">
#         📊 Question 1: Does average annual income differ across employment status groups?
#     </h3>
#
# </div>

# %%
df.groupby('Employment_Status')['Annual_Income_Usd'].mean().sort_values(ascending=False)
# Out:
# Employment_Status
# Self-Employed   174437.83
# Salaried        149407.50
# Retired          65974.73
# Student          13261.92
# Unemployed        5176.89
# Name: Annual_Income_Usd, dtype: float64

# %% [markdown]
# <div style="background:#fdf2f8;padding:16px;border-radius:10px;border:1px solid #fbcfe8;">
# <b style="color:#be185d;font-size:15px;">💡 Insight</b><br>
# <span style="color:#475569;"><b>* </b> Annual income differs substantially across employment statuses. Self-employed clients have the highest average annual income at 174,437.83 usd, followed by salaried clients at 149,407.50 usd. Retired clients have a considerably lower average income of 65,974.73 usd, while students 13,261.92 usd and unemployed clients 5176.89 usd have the lowest average incomes.
#     <br/><p>Overall, the results show a clear relationship between employment status and annual income, with clients who are employed or self-employed generally earning substantially more than those who are retired, students, or unemployed.</p>
# </span>
# </div>

# %% [markdown]
# <div style="
#     margin:30px 0 20px 0;
#     padding:0 0 12px 0;
#     border-bottom:2px solid #2563eb;">
#   <h3 style="
#         margin:0;
#         color:#0f172a;
#         font-size:15px;
#         font-weight:700;
#         line-height:1.5;
#     ">
#         📊 Question 2: Does risk tolerance differ across age groups?
#     </h3>
#
# </div>

# %%
df.groupby('Age_Group',observed=True)['Risk_Tolerance_1_10'].mean()
# Out:
# Age_Group
# Young         5.39
# Middle-Aged   2.72
# Senior        3.51
# Older         4.38
# Name: Risk_Tolerance_1_10, dtype: float64

# %% [markdown]
# <div style="background:#fdf2f8;padding:16px;border-radius:10px;border:1px solid #fbcfe8;">
# <b style="color:#be185d;font-size:15px;">💡 Insight</b><br>
# <span style="color:#475569;"><b>* </b>Young clients show the highest average risk tolerance (5.39), while Middle-Aged clients have the lowest (2.72). Older (4.38) and Senior (3.51) clients fall between these groups, suggesting noticeable differences in risk tolerance across age groups.</span>
# </div>

# %% [markdown]
# <div style="
#     margin:30px 0 20px 0;
#     padding:0 0 12px 0;
#     border-bottom:2px solid #2563eb;">
#   <h3 style="
#         margin:0;
#         color:#0f172a;
#         font-size:15px;
#         font-weight:700;
#         line-height:1.5;
#     ">
#         📊 Question 3: Is there a relationship between a client's age and the size of their investment portfolio?
#     </h3>
#
# </div>

# %%
df['Age'].corr(df['Investment_Portfolio_Usd'])
# Out:
# np.float64(0.5118655285453856)

# %% [markdown]
# <div style="background:#fdf2f8;padding:16px;border-radius:10px;border:1px solid #fbcfe8;">
# <b style="color:#be185d;font-size:15px;">💡 Insight</b><br>
# <span style="color:#475569;"><b>* </b>There is a moderate positive correlation of around 0.51 between age and portfolio size.
# Older clients tend to hold larger investment portfolios consistent with more years of accumulation,
# though the relationship is far from perfect, meaning age alone doesn't fully determine portfolio size.</span>
# </div>

# %% [markdown]
# <div style="
#     margin:30px 0 20px 0;
#     padding:0 0 12px 0;
#     border-bottom:2px solid #2563eb;">
#   <h3 style="
#         margin:0;
#         color:#0f172a;
#         font-size:15px;
#         font-weight:700;
#         line-height:1.5;
#     ">
#         📊 Question 4: Does debt vary across employment status?
#     </h3>
#
# </div>

# %%
df.groupby('Employment_Status')['Total_Debt_Usd'].mean().sort_values(ascending=False)
# Out:
# Employment_Status
# Self-Employed   274187.29
# Salaried        234527.74
# Retired          56817.20
# Student          16054.79
# Unemployed        7057.18
# Name: Total_Debt_Usd, dtype: float64

# %% [markdown]
# <div style="background:#fdf2f8;padding:16px;border-radius:10px;border:1px solid #fbcfe8;">
# <b style="color:#be185d;font-size:15px;">💡 Insight</b><br>
# <span style="color:#475569;"><b>* </b>Average debt varies significantly across employment statuses. Self-Employed clients have the highest average debt at 274,187.29 usd, followed by Salaried clients at 234,527.74 usd. Retired clients have a considerably lower average debt of 56,817.20 usd, while Students 16,054.79 usd and Unemployed clients 7,057.18 usd have the lowest average debt.<br/> Overall, the results suggest that Self-Employed and Salaried clients tend to carry substantially higher levels of debt compared with the other employment groups.</span>
# </div>

# %% [markdown]
# <div style="
#     margin:30px 0 20px 0;
#     padding:0 0 12px 0;
#     border-bottom:2px solid #2563eb;">
#   <h3 style="
#         margin:0;
#         color:#0f172a;
#         font-size:15px;
#         font-weight:700;
#         line-height:1.5;
#     ">
#         📊 Question 5: Does client satisfaction differ depending on the preferred communication channel?
#     </h3>
#
# </div>

# %%
df.groupby('Preferred_Channel')['User_Satisfaction_1_5'].mean().sort_values(ascending=False)
# Out:
# Preferred_Channel
# In-Person   2.76
# Chat        2.75
# Email       2.73
# Phone       2.72
# App         2.69
# Name: User_Satisfaction_1_5, dtype: float64

# %% [markdown]
# <div style="background:#fdf2f8;padding:16px;border-radius:10px;border:1px solid #fbcfe8;">
# <b style="color:#be185d;font-size:15px;">💡 Insight</b><br>
# <span style="color:#475569;"><b>* </b>Average client satisfaction is relatively consistent across all preferred communication channels,
# ranging from 2.69 to 2.76. Chat and In-Person channels have the highest average satisfaction at 2.76 and 2.75 respectively while App has the
# lowest at 2.69. The small difference of only 0.07 points suggests that the preferred communication channel has little variation in
# overall client satisfaction.</span>
# </div>

# %% [markdown]
# <div style="
#     margin:30px 0 20px 0;
#     padding:0 0 12px 0;
#     border-bottom:2px solid #2563eb;">
#   <h3 style="
#         margin:0;
#         color:#0f172a;
#         font-size:15px;
#         font-weight:700;
#         line-height:1.5;
#     ">
#         📊 Question 6: Does risk tolerance vary by marital status?
#     </h3>
#
# </div>

# %%
marital_risk = df.groupby('Marital_Status')['Risk_Tolerance_1_10'].agg(
    ['mean', 'median', 'std', 'count']
)

marital_risk
# Out:
#                 mean  median  std  count
# Marital_Status
# Divorced        4.06    4.03 1.45    719
# Married         4.00    3.98 1.43   2799
# Single          4.10    4.00 1.38   1254
# Widowed         4.02    4.04 1.38    228

# %% [markdown]
# <div style="background:#fdf2f8;padding:16px;border-radius:10px;border:1px solid #fbcfe8;">
# <b style="color:#be185d;font-size:15px;">💡 Insight</b><br>
# <span style="color:#475569;"><b>* </b>Risk tolerance varies only slightly by marital status. Single individuals show the highest risk tolerance, while married individuals show the lowest, but the differences are small.
# </span>
# </div>

# %% [markdown]
# <div style="
#     margin:30px 0 14px 0;
#     padding:15px 20px;
#     background:linear-gradient(90deg,#2563eb 0%,#0f172a 100%);
#     border-radius:12px;
#     color:white;">
#     <h2 style="margin:0;color:white;font-size:18px;">Multivariate Analysis</h2>
#     </div>

# %% [markdown]
# <div style="
#     margin:30px 0 20px 0;
#     padding:0 0 12px 0;
#     border-bottom:2px solid #2563eb;">
#   <h3 style="
#         margin:0;
#         color:#0f172a;
#         font-size:15px;
#         font-weight:700;
#         line-height:1.5;
#     ">
#         📊 Question 1: How does average debt size vary jointly by employment status and marital status?
#     </h3>
#
# </div>

# %%
df.groupby(['Employment_Status','Marital_Status'])['Total_Debt_Usd'].mean().sort_values(ascending=False)
# Out:
# Employment_Status  Marital_Status
# Self-Employed      Widowed          349849.20
#                    Single           281026.39
#                    Divorced         280744.27
#                    Married          265101.65
# Salaried           Divorced         242113.60
#                    Married          235678.65
#                    Widowed          229173.06
#                    Single           228274.32
# Retired            Single            60531.47
#                    Divorced          57140.82
#                    Married           55848.86
#                    Widowed           46844.26
# Student            Divorced          18445.09
#                    Widowed           17326.28
#                    Single            17076.29
#                    Married           14716.85
# Unemployed         Widowed            9831.46
#                    Divorced           8204.77
#                    Married            6763.39
#                    Single             6332.60
# ...

# %% [markdown]
# <div style="background:#fdf2f8;padding:16px;border-radius:10px;border:1px solid #fbcfe8;">
# <b style="color:#be185d;font-size:15px;">💡 Insight</b><br>
# <span style="color:#475569;"><b>* </b>The analysis shows that employment status has a strong relationship with total debt. Self-employed individuals have the highest average debt,
# especially widowed individuals 3,49,849.20 usd, while unemployed individuals have the lowest debt.<br/><b>* </b> Salaried individuals also have relatively high
# debt across all marital statuses. <br/><b>* </b>Marital status shows some differences within each employment group, but the pattern is not consistent. <br/><b>* </b>Overall,
# the results suggest that employment status has a stronger influence on total debt than marital status.
#
# </span>
# </div>

# %% [markdown]
# <div style="
#     margin:30px 0 20px 0;
#     padding:0 0 12px 0;
#     border-bottom:2px solid #2563eb;">
#   <h3 style="
#         margin:0;
#         color:#0f172a;
#         font-size:15px;
#         font-weight:700;
#         line-height:1.5;
#     ">
#         📊 Question 2: How does client satisfaction vary jointly by risk category and employment status?
#     </h3>
#
# </div>

# %%
df.groupby(['Risk_Category', 'Employment_Status'],observed=True)['User_Satisfaction_1_5'].mean().sort_values(ascending=False).round(2)
# Out:
# Risk_Category  Employment_Status
# High Risk      Unemployed          3.21
#                Student             2.93
# Low Risk       Self-Employed       2.86
# Moderate Risk  Self-Employed       2.84
# Low Risk       Salaried            2.83
# Moderate Risk  Salaried            2.79
#                Retired             2.69
# Low Risk       Retired             2.57
# Moderate Risk  Student             2.56
#                Unemployed          2.50
# High Risk      Salaried            2.50
# Low Risk       Unemployed          1.99
# Name: User_Satisfaction_1_5, dtype: float64

# %% [markdown]
# <div style="background:#fdf2f8;padding:16px;border-radius:10px;border:1px solid #fbcfe8;">
# <b style="color:#be185d;font-size:15px;">💡 Insight</b><br>
# <span style="color:#475569;"><b>* </b> The average satisfaction scores range from 1.99 to 3.21 out of 5, indicating generally moderate satisfaction.
# <br/><b>* </b>The combination matters: within High Risk, Unemployed clients report the highest
# satisfaction (3.21), while within Low Risk, Unemployed clients report the lowest (1.99) —
# the opposite pattern. <br/><b>* </b>Self-employed customers show relatively consistent satisfaction across Low and Moderate Risk categories (2.86 and 2.84, respectively).
# <br/><b>* </b>Overall, the results suggest that there is no clear linear relationship between risk category and user satisfaction, and employment status may play an important role in explaining differences in satisfaction.
# </span>
# </div>

# %% [markdown]
# <div style="
#     margin:30px 0 20px 0;
#     padding:0 0 12px 0;
#     border-bottom:2px solid #2563eb;">
#   <h3 style="
#         margin:0;
#         color:#0f172a;
#         font-size:15px;
#         font-weight:700;
#         line-height:1.5;
#     ">
#         📊 Question 3: How does average risk tolerance vary across the combination of age group and risk category?
#     </h3>
#
# </div>

# %%
df.pivot_table(index='Age_Group', columns='Risk_Category', values='Risk_Tolerance_1_10',observed=False).round(2)
# Out:
# Risk_Category  Low Risk  Moderate Risk  High Risk
# Age_Group
# Young              2.22           5.44       7.94
# Middle-Aged        1.80           3.64       8.66
# Senior             2.21           4.00       7.62
# Older              2.51           4.53       7.83

# %% [markdown]
# <div style="background:#fdf2f8;padding:16px;border-radius:10px;border:1px solid #fbcfe8;">
# <b style="color:#be185d;font-size:15px;">💡 Insight</b><br>
# <span style="color:#475569;"><b>* </b>Within every age group, High Risk-labeled clients score far higher on risk tolerance
# (7.6 – 8.6) than Moderate (3.6 – 5.4) or Low (1.8 – 2.5) confirming the risk labels are internally consistent.
# <br/><b>* </b>Interestingly, Middle-Aged High Risk clients have the highest tolerance score of all (8.66), while
# Young Moderate Risk clients score notably higher (5.44) than their Moderate-Risk in other age
# groups, younger moderate clients lean more risk-tolerant within their own category.
# </span>
# </div>

# %% [markdown]
# <div style="
#     margin:30px 0 20px 0;
#     padding:0 0 12px 0;
#     border-bottom:2px solid #2563eb;">
#   <h3 style="
#         margin:0;
#         color:#0f172a;
#         font-size:15px;
#         font-weight:700;
#         line-height:1.5;
#     ">
#         📊 Question 4: Does satisfaction vary jointly by preferred channel and check-in frequency?
#     </h3>
#
# </div>

# %%
df.pivot_table(values='User_Satisfaction_1_5',index='Preferred_Channel',columns='Checkin_Frequency')
# Out:
# Checkin_Frequency  Ad-hoc  Annual  Biannual  Monthly  Quarterly
# Preferred_Channel
# App                  2.44    2.50      2.61     2.96       2.70
# Chat                 2.60    2.49      2.63     3.15       2.74
# Email                2.67    2.52      2.61     2.93       2.82
# In-Person            2.52    2.49      2.65     3.04       2.88
# Phone                2.58    2.48      2.62     3.01       2.81

# %% [markdown]
# <div style="background:#fdf2f8;padding:16px;border-radius:10px;border:1px solid #fbcfe8;">
# <b style="color:#be185d;font-size:15px;">💡 Insight</b><br>
# <span style="color:#475569;"><b>* </b>The pivot table indicates that client satisfaction varies across different communication channels and check-in frequencies. <br/><b>* </b>Client satisfaction is generally higher among those with Monthly check-ins and lower for Annual and Ad-hoc check-ins. <br/><b>* </b> The highest satisfaction score is for Chat users with Monthly check-ins (3.15), while the lowest is for App users with Ad-hoc check-ins (2.44).
# <br/><b>* </b> Overall, more frequent check-ins are associated with higher satisfaction.
# </span>
# </div>

# %% [markdown]
# <div style="
#     margin:30px 0 20px 0;
#     padding:0 0 12px 0;
#     border-bottom:2px solid #2563eb;">
#   <h3 style="
#         margin:0;
#         color:#0f172a;
#         font-size:15px;
#         font-weight:700;
#         line-height:1.5;
#     ">
#         📊 Question 5: How do debt-to-income and portfolio-to-income ratios vary jointly by employment status and risk category?
#     </h3>
#
# </div>

# %%
df.groupby(['Employment_Status', 'Risk_Category'],observed=False)[['Debt_Income_Ratio', 'Portfolio_Income_Ratio']].mean().round(3)
# Out:
#                                  Debt_Income_Ratio  Portfolio_Income_Ratio
# Employment_Status Risk_Category
# Retired           Low Risk                    0.71                    4.30
#                   Moderate Risk               0.94                    6.51
#                   High Risk                    NaN                     NaN
# Salaried          Low Risk                    2.20                    1.85
#                   Moderate Risk               1.40                    2.10
#                   High Risk                   0.65                    0.00
# Self-Employed     Low Risk                    2.19                    2.24
#                   Moderate Risk               1.35                    2.53
#                   High Risk                    NaN                     NaN
# Student           Low Risk                     NaN                     NaN
#                   Moderate Risk               2.12                    1.50
# ...

# %% [markdown]
# <div style="background:#fdf2f8;padding:16px;border-radius:10px;border:1px solid #fbcfe8;">
# <b style="color:#be185d;font-size:15px;">💡 Insight</b><br>
# <span style="color:#475569;"><b>* </b>Unemployed, High Risk clients stand out with an extreme portfolio-to-income ratio
# (36.89) — their portfolios are huge relative to their (very low) reported income, likely reflecting
# pre-existing wealth rather than earnings. <br/><b>* </b>Student, High Risk clients also show a high ratio (21.98).
# <br/><b>* </b>Debt-to-income ratios are highest for Unemployed, Low Risk clients (5.92), meaning this subgroup is
# most financially strained relative to income — the two ratios tell different, complementary stories
# depending on the employment/risk combination.
# </span>
# </div>

# %% [markdown]
# <div style="
#     margin:30px 0 20px 0;
#     padding:0 0 12px 0;
#     border-bottom:2px solid #2563eb;">
#   <h3 style="
#         margin:0;
#         color:#0f172a;
#         font-size:15px;
#         font-weight:700;
#         line-height:1.5;
#     ">
#         📊 Question 6: Which combination of marital status and primary goal is associated with the highest average target savings amount?
#     </h3>
#
# </div>

# %%
df.groupby(['Marital_Status', 'Primary_Goal'])['Target_Amount_Usd'].mean().round(0).sort_values(ascending=False)
# Out:
# Marital_Status  Primary_Goal
# Married         Retirement            3195806.00
# Widowed         Retirement            3181740.00
# Single          Retirement            3123611.00
# Divorced        Retirement            3063568.00
# Widowed         Estate Planning       1217132.00
# Divorced        Estate Planning       1103840.00
# Single          Estate Planning       1019727.00
# Married         Estate Planning        999256.00
# Divorced        Home Purchase          656626.00
# Married         Home Purchase          636320.00
# Single          Home Purchase          584340.00
# Widowed         Home Purchase          522688.00
#                 Business Investment    285662.00
# Single          Business Investment    269818.00
# Divorced        Business Investment    264332.00
# Married         Business Investment    240692.00
# Single          Healthcare             184932.00
# Widowed         Healthcare             184009.00
# Divorced        Healthcare             171394.00
# ...

# %% [markdown]
# <div style="background:#fdf2f8;padding:16px;border-radius:10px;border:1px solid #fbcfe8;">
# <b style="color:#be185d;font-size:15px;">💡 Insight</b><br>
# <span style="color:#475569;"><b>* </b>Retirement goals dominate the top of the list regardless of marital status, led by Married clients saving for retirement (
# 3,195,806.00 usd). <br/><b>* </b>Estate Planning targets form the next tier (~ 1.0 m - 1.2M). Marital status shifts the target amount somewhat, but the type of goal is the dominant factor.<br/><b>* </b> At the same time, saving for the travel goal recorded the least among.
# </span>
# </div>

# %% [markdown]
# <div style="
#     margin:30px 0 14px 0;
#     padding:15px 20px;
#     background:linear-gradient(90deg,#2563eb 0%,#0f172a 100%);
#     border-radius:12px;
#     color:white;">
#     <h2 style="margin:0;color:white;font-size:25px;">Phase 3 - Data Visualization</h2>
#     </div>

# %% [markdown]
# <div style="
#     margin:30px 0 14px 0;
#     padding:15px 20px;
#     background:linear-gradient(90deg,#2563eb 0%,#0f172a 100%);
#     border-radius:12px;
#     color:white;">
#     <h2 style="margin:0;color:white;font-size:18px;">Univariate Analysis</h2>
#     </div>

# %% [markdown]
# <div style="
#     margin:30px 0 20px 0;
#     padding:0 0 12px 0;
#     border-bottom:2px solid #2563eb;">
#   <h3 style="
#         margin:0;
#         color:#0f172a;
#         font-size:15px;
#         font-weight:700;
#         line-height:1.5;
#     ">
#         📊 Question 1: What is the distribution of annual income usd, log transformed income, monthly expenses and disposible income which is calcuted from monthly income and expenses among clients?
#     </h3>
#
# </div>

# %%
plt.figure(figsize=(20,15))
plt.subplot(2,2,1)
plt.hist(df['Annual_Income_Usd'],bins=20,edgecolor='black')
plt.xlabel('Annual Income in (USD)',fontweight='bold')
plt.ylabel('Frequency',fontweight='bold')
plt.title('Distribution of Annual Income',fontweight='bold')

plt.subplot(2,2,2)
plt.hist(df['Total_Debt_Usd'],bins=20,edgecolor='black')
plt.xlabel('Total Debt in (USD) ',fontweight='bold')
plt.ylabel('Frequency',fontweight='bold')
plt.title('Distribution of Total Debt of Clients',fontweight='bold')

plt.subplot(2,2,3)
plt.hist(df['Monthly_Expenses_Usd'],bins=20,edgecolor='black')
plt.xlabel('Monthly Expenses in (USD)',fontweight='bold')
plt.ylabel('Frequency',fontweight='bold')
plt.title('Distribution of Monthly Expenses',fontweight='bold')

plt.subplot(2,2,4)
plt.hist(df['Disposable_Income_Usd'],bins=20,edgecolor='black')
plt.xlabel(' Monthly Disposible Income After Monthly Expenses in(USD)',fontweight='bold')
plt.ylabel('Frequency',fontweight='bold')
plt.title('Distribution of Disposible Income',fontweight='bold')

plt.show()

# %% [markdown]
# <div style="background:#fdf2f8;padding:16px;border-radius:10px;border:1px solid #fbcfe8;">
# <b style="color:#be185d;font-size:15px;">💡 Conclusion</b><br>
# <span style="color:#475569;">
# <b>* </b>Annual income, total debt, monthly expenses, and disposable income are all right-skewed, with most clients showing lower-to-moderate values and a few clients having very high values in all of them.
# </span>
# </div>

# %% [markdown]
# <div style="
#     margin:30px 0 20px 0;
#     padding:0 0 12px 0;
#     border-bottom:2px solid #2563eb;">
#   <h3 style="
#         margin:0;
#         color:#0f172a;
#         font-size:15px;
#         font-weight:700;
#         line-height:1.5;
#     ">
#         📊 Question 2: What does the overall age distribution of clients look like?
#     </h3>
#
# </div>

# %%
sns.histplot(df['Age'],bins=20,kde=True,color='#4C72B0')
plt.title('Distribution of Client Age')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# <div style="background:#fdf2f8;padding:16px;border-radius:10px;border:1px solid #fbcfe8;">
# <b style="color:#be185d;font-size:15px;">💡 Insight</b><br>
# <span style="color:#475569;">
# <b>* </b>The histogram shows a fairly broad, multi-peaked spread across 18–85 years rather
# than one sharp peak visually confirming the earlier finding that clients aren't concentrated in a single life stage. <br/><b>* </b>There's a mild rise in counts through the 40s–60s range.
# </span>
# </div>

# %% [markdown]
# <div style="
#     margin:30px 0 20px 0;
#     padding:0 0 12px 0;
#     border-bottom:2px solid #2563eb;">
#   <h3 style="
#         margin:0;
#         color:#0f172a;
#         font-size:15px;
#         font-weight:700;
#         line-height:1.5;
#     ">
#         📊 Question 3: Whether customer base is dominated by high risk,moderate risk or low risk?
#     </h3>
#
# </div>

# %%
sns.countplot(x='Risk_Category',data=df)
plt.title('Distribution of clients in High,Moderate and Low Risk Category')
plt.xlabel('Risk Category')
plt.ylabel('Count of Clients')
plt.show()

# %% [markdown]
# <div style="background:#fdf2f8;padding:16px;border-radius:10px;border:1px solid #fbcfe8;">
# <b style="color:#be185d;font-size:15px;">💡 Insight</b><br>
# <span style="color:#475569;">
# <b>* </b>Majority of the clients belong to the moderate risk at around 3600 followed by low risk clients at around 900.The high risk clients are the least among these three categories.</span>
# </div>

# %% [markdown]
# <div style="
#     margin:30px 0 20px 0;
#     padding:0 0 12px 0;
#     border-bottom:2px solid #2563eb;">
#   <h3 style="
#         margin:0;
#         color:#0f172a;
#         font-size:15px;
#         font-weight:700;
#         line-height:1.5;
#     ">
#         📊 Question 4: Distribution of preferred channel preference among clients?
#     </h3>
#
# </div>

# %%
fig = px.pie(df, names='Preferred_Channel',
             title='Distribution of Preferred Communication Channel')
fig.show()

# %% [markdown]
# <div style="background:#fdf2f8;padding:16px;border-radius:10px;border:1px solid #fbcfe8;">
# <b style="color:#be185d;font-size:15px;">💡 Insight</b><br>
# <span style="color:#475569;">
# <b>* </b>Among the communication channels, almost 30% of clients chose Email, while around 26% opted for the App and around 21% selected Phone as their preferred communication medium.
# <br>
# <b>* </b>In-person communication was preferred by around 16% of clients, whereas Chat was the least preferred channel, accounting for only 6.5% of clients.
# </span>
# </div>

# %% [markdown]
# <div style="
#     margin:30px 0 20px 0;
#     padding:0 0 12px 0;
#     border-bottom:2px solid #2563eb;">
#   <h3 style="
#         margin:0;
#         color:#0f172a;
#         font-size:15px;
#         font-weight:700;
#         line-height:1.5;
#     ">
#         📊 Question 5: Frequency Distribution of Credit Score?
#     </h3>
#
# </div>

# %%
sns.displot(df['Credit_Score'], bins=10, kde=True, color='b')

plt.xlabel('Credit Score')
plt.ylabel('Frequency')
plt.title('Distribution of Credit Score')

plt.show()

# %% [markdown]
# <div style="background:#fdf2f8;padding:16px;border-radius:10px;border:1px solid #fbcfe8;">
# <b style="color:#be185d;font-size:15px;">💡 Insight</b><br>
# <span style="color:#475569;">
# <b>* </b>Most clients have credit scores between 400 and 500, with the highest concentration around 450–470. Very few clients have extremely low or high credit scores, indicating that the majority of clients have moderate to good credit profiles.
# </span>
# </div>

# %% [markdown]
# <div style="
#     margin:30px 0 20px 0;
#     padding:0 0 12px 0;
#     border-bottom:2px solid #2563eb;">
#   <h3 style="
#         margin:0;
#         color:#0f172a;
#         font-size:15px;
#         font-weight:700;
#         line-height:1.5;
#     ">
#         📊 Question 6: Visually, how concentrated is the client base in the Moderate Risk category?
#     </h3>
#
# </div>

# %%
fig = px.pie(df, names='Risk_Category',
             title='Distribution of Clients by Risk Category',
             hole=0.4)
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()

# %% [markdown]
# <div style="background:#fdf2f8;padding:16px;border-radius:10px;border:1px solid #fbcfe8;">
# <b style="color:#be185d;font-size:15px;">💡 Insight</b><br>
# <span style="color:#475569;">
# <b>* </b>The Moderate Risk slice occupies nearly four-fifths of the circle at 78.2%, Low Risk at 21.3%, and High Risk at only 0.6%, visually
# shows how rare the presence of high-risk clients are.</span>
# </div>

# %% [markdown]
# <div style="
#     margin:30px 0 14px 0;
#     padding:15px 20px;
#     background:linear-gradient(90deg,#2563eb 0%,#0f172a 100%);
#     border-radius:12px;
#     color:white;">
#     <h2 style="margin:0;color:white;font-size:18px;">Bivariate Analysis</h2>
#     </div>

# %% [markdown]
# <div style="
#     margin:30px 0 20px 0;
#     padding:0 0 12px 0;
#     border-bottom:2px solid #2563eb;">
#   <h3 style="
#         margin:0;
#         color:#0f172a;
#         font-size:15px;
#         font-weight:700;
#         line-height:1.5;
#     ">
#         📊 Question 1: Do clients with higher incomes generally have larger investment portfolios?
#     </h3>
#
# </div>

# %%
sns.scatterplot(data=df,x='Annual_Income_Usd',y='Investment_Portfolio_Usd',color='b')

plt.title('Annual Income vs Investment Portfolio')
plt.xlabel('Annual Income (USD)')
plt.ylabel('Investment Portfolio (USD)')

plt.show()

# %% [markdown]
# <div style="background:#fdf2f8;padding:16px;border-radius:10px;border:1px solid #fbcfe8;">
# <b style="color:#be185d;font-size:15px;">💡 Insight</b><br>
# <span style="color:#475569;">
# <b>* </b>Annual income and investment portfolio show a positive relationship, with higher-income clients generally having larger investment portfolios. However, considerable variation is observed and also certain clients have relatively high income and also investment.
# </span>
# </div>

# %% [markdown]
# <div style="
#     margin:30px 0 20px 0;
#     padding:0 0 12px 0;
#     border-bottom:2px solid #2563eb;">
#   <h3 style="
#         margin:0;
#         color:#0f172a;
#         font-size:15px;
#         font-weight:700;
#         line-height:1.5;
#     ">
#         📊 Question 2: Does distribution of Annual Income in Usd is equally distributed between all age groups?
#     </h3>
#
# </div>

# %%
sns.jointplot(x=df['Annual_Income_Usd'],y=df['Age'],kind='hex',palette='viridis')
plt.suptitle('Distribution of Annual Income by Age Group', y=1.02) 
plt.xlabel('Annual Income (USD)')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# <div style="background:#fdf2f8;padding:16px;border-radius:10px;border:1px solid #fbcfe8;">
# <b style="color:#be185d;font-size:15px;">💡 Insight</b><br>
# <span style="color:#475569;">
# <b>* </b>Most clients across different age groups have low-to-moderate annual incomes, while a few high-income clients also exists across various ages.
#     <br/><b>* </b> So the annual income is not equally distributed among all age groups.
# </span>
# </div>

# %% [markdown]
# <div style="
#     margin:30px 0 20px 0;
#     padding:0 0 12px 0;
#     border-bottom:2px solid #2563eb;">
#   <h3 style="
#         margin:0;
#         color:#0f172a;
#         font-size:15px;
#         font-weight:700;
#         line-height:1.5;
#     ">
#         📊 Question 3: Do clients with different financial risk profiles have different satisfaction levels?
#     </h3>
#
# </div>

# %%
sns.boxplot(data=df,x='Risk_Category',y='User_Satisfaction_1_5',color='b')

plt.title('User Satisfaction by Risk Category')
plt.xlabel('Risk Category')
plt.ylabel('User Satisfaction (1–5)')

plt.show()

# %% [markdown]
# <div style="background:#fdf2f8;padding:16px;border-radius:10px;border:1px solid #fbcfe8;">
# <b style="color:#be185d;font-size:15px;">💡 Insight</b><br>
# <span style="color:#475569;">
# <b>* </b>High-risk clients have higher user satisfaction than low- and moderate-risk clients, while low and moderate risk show almost similar satisfaction levels.</span></div>

# %% [markdown]
# <div style="
#     margin:30px 0 20px 0;
#     padding:0 0 12px 0;
#     border-bottom:2px solid #2563eb;">
#   <h3 style="
#         margin:0;
#         color:#0f172a;
#         font-size:15px;
#         font-weight:700;
#         line-height:1.5;
#     ">
#         📊 Question 4: Does risk tolerance visibly shift across marital status groups?
#     </h3>
#
# </div>

# %%
plt.figure(figsize=(7,4))
sns.violinplot(data=df, x='Marital_Status', y='Risk_Tolerance_1_10', palette='Set3', hue='Marital_Status',legend=False, inner='quartile')
plt.title('Risk Tolerance by Marital Status (Violin Plot)')
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background:#fdf2f8;padding:16px;border-radius:10px;border:1px solid #fbcfe8;">
# <b style="color:#be185d;font-size:15px;">💡 Insight</b><br>
# <span style="color:#475569;">
# <b>* </b> The violin shapes for all four marital status groups look almost identical in width and
# median line position visually confirming that marital status has little to no distinguishing effect
# on risk tolerance.</span></div>

# %% [markdown]
# <div style="
#     margin:30px 0 20px 0;
#     padding:0 0 12px 0;
#     border-bottom:2px solid #2563eb;">
#   <h3 style="
#         margin:0;
#         color:#0f172a;
#         font-size:15px;
#         font-weight:700;
#         line-height:1.5;
#     ">
#         📊 Question 5: How does the emergency fund cushion compare visually across risk categories?
#     </h3>
#
# </div>

# %%
plt.figure(figsize=(6,4))
sns.pointplot(data=df, x='Risk_Category', y='Emergency_Fund_Months',
               palette='viridis', linestyles='-', markers='o',hue='Risk_Category',legend=False)
plt.title('Average Emergency Fund Cushion by Risk Category')
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background:#fdf2f8;padding:16px;border-radius:10px;border:1px solid #fbcfe8;">
# <b style="color:#be185d;font-size:15px;">💡 Insight</b><br>
# <span style="color:#475569;">
# <b>* </b> The analysis indicates that emergency-fund preparedness varies across risk categories.<br/><b>* </b> Moderate Risk customers have the highest average emergency-fund coverage at approximately 3.4 months, followed by Low Risk customers at around 3.3 months. <br/><b>* </b> High Risk customers have the lowest average coverage at approximately 2.5 months.<br/><b>* </b> This suggests that customers classified as High Risk may have weaker financial buffers to handle unexpected expenses.<br/><b>* </b> The wider 95% confidence interval for the High Risk group also indicates greater uncertainty or variability in emergency-fund levels compared with the other groups.<br/><b>* </b> Overall, emergency-fund coverage appears to be an important characteristic distinguishing customers across risk categories.</span></div>

# %% [markdown]
# <div style="
#     margin:30px 0 20px 0;
#     padding:0 0 12px 0;
#     border-bottom:2px solid #2563eb;">
#   <h3 style="
#         margin:0;
#         color:#0f172a;
#         font-size:15px;
#         font-weight:700;
#         line-height:1.5;
#     ">
#         📊 Question 6: Does average satisfaction visibly differ by preferred channel, and by how much?
#     </h3>
#
# </div>

# %%
avg_satisfaction_by_channel = df.groupby('Preferred_Channel')['User_Satisfaction_1_5'].mean().reset_index()

plt.figure(figsize=(7,4))
sns.barplot(data=avg_satisfaction_by_channel, x='Preferred_Channel', y='User_Satisfaction_1_5', 
            palette='viridis',hue='Preferred_Channel',legend=False)
plt.title('Average User Satisfaction by Preferred Communication Channel')
plt.xlabel('Preferred Channel')
plt.ylabel('Average User Satisfaction (1-5)')

plt.show()

# %% [markdown]
# <div style="background:#fdf2f8;padding:16px;border-radius:10px;border:1px solid #fbcfe8;">
# <b style="color:#be185d;font-size:15px;">💡 Insight</b><br>
# <span style="color:#475569;">
# <b>* </b>The bars are nearly the same height across all five channels (all hovering around
# 2.7–2.8)and identified that channel choice does not
# produce a meaningfully different satisfaction outcome.</span></div>

# %% [markdown]
# <div style="
#     margin:30px 0 14px 0;
#     padding:15px 20px;
#     background:linear-gradient(90deg,#2563eb 0%,#0f172a 100%);
#     border-radius:12px;
#     color:white;">
#     <h2 style="margin:0;color:white;font-size:18px;">Multivariate Analysis</h2>
#     </div>

# %% [markdown]
# <div style="
#     margin:30px 0 20px 0;
#     padding:0 0 12px 0;
#     border-bottom:2px solid #2563eb;">
#   <h3 style="
#         margin:0;
#         color:#0f172a;
#         font-size:15px;
#         font-weight:700;
#         line-height:1.5;
#     ">
#         📊 Question 1: How are Annual Income, Total Debt are shared among different risk cateogry of clients?
# </h3>
# </div>

# %%
fig = px.scatter(
    df,
    x='Annual_Income_Usd',
    y='Total_Debt_Usd',
    color='Risk_Category',
    title='Relationship Between Income and Debt by Risk Category')
fig.show()

# %% [markdown]
# <div style="background:#fdf2f8;padding:16px;border-radius:10px;border:1px solid #fbcfe8;">
# <b style="color:#be185d;font-size:15px;">💡 Insight</b><br>
# <span style="color:#475569;">
# <b>* </b>The scatter plot shows a positive relationship between Annual Income and Total Debt, indicating that clients with higher incomes generally tend to have higher levels of debt. Most clients are concentrated in the low-to-moderate income and debt range, while a few clients have high income and also high debt amount. Risk categories also show different patterns, with Low Risk clients forming a large portion of the central cluster whereas high risk become the minority.</span></div>.

# %% [markdown]
# <div style="
#     margin:30px 0 20px 0;
#     padding:0 0 12px 0;
#     border-bottom:2px solid #2563eb;">
#   <h3 style="
#         margin:0;
#         color:#0f172a;
#         font-size:15px;
#         font-weight:700;
#         line-height:1.5;
#     ">
#         📊 Question 2: How Annual Income (USD) is distributed across different Age Groups, separated by Risk Category.
# </h3>
# </div>

# %%
fig = px.violin(df,
    x='Age_Group',
    y='Annual_Income_Usd',
    color='Risk_Category',
    title='Annual Income by Age Group and Risk Category'
)
fig.show()

# %% [markdown]
# <div style="background:#fdf2f8;padding:16px;border-radius:10px;border:1px solid #fbcfe8;">
# <b style="color:#be185d;font-size:15px;">💡 Insight</b><br>
# <span style="color:#475569;">
#    <b>* </b>Moderate-risk clients generally have higher and more consistently distributed incomes, while high-risk clients tend to have substantially lower incomes. Low-risk clients show greater variability, including some very high-income observations.
#  </span></div>.

# %% [markdown]
# <div style="
#     margin:30px 0 20px 0;
#     padding:0 0 12px 0;
#     border-bottom:2px solid #2563eb;">
#   <h3 style="
#         margin:0;
#         color:#0f172a;
#         font-size:15px;
#         font-weight:700;
#         line-height:1.5;
#     ">
#         📊 Question 3: How do monthly expenses vary across employment status and marital status?
# </h3>
# </div>

# %%
expense_summary = (df.groupby(['Employment_Status', 'Marital_Status'])['Monthly_Expenses_Usd'].mean().reset_index())
fig = px.bar(expense_summary,
             x='Employment_Status',
             y='Monthly_Expenses_Usd',
             color='Marital_Status',
             title='Average Monthly Expenses by Employment and Marital Status'
)
fig.show()

# %% [markdown]
# <div style="background:#fdf2f8;padding:16px;border-radius:10px;border:1px solid #fbcfe8;">
# <b style="color:#be185d;font-size:15px;">💡 Insight</b><br>
# <span style="color:#475569;">
#    <b>* </b>The analysis shows that employment status has a strong relationship with monthly expenses.<br/><b>* </b> Self-employed and salaried individuals have the highest average expenses, whereas students and unemployed individuals have the lowest.<br/><b>* </b> Marital status also creates slight variation within each employment group, indicating that both employment and family circumstances may influence monthly spending.</span></div>.

# %% [markdown]
# <div style="
#     margin:30px 0 20px 0;
#     padding:0 0 12px 0;
#     border-bottom:2px solid #2563eb;">
#   <h3 style="
#         margin:0;
#         color:#0f172a;
#         font-size:15px;
#         font-weight:700;
#         line-height:1.5;
#     ">
#         📊 Question 4: How does investment portfolio value vary across age groups and risk categories?
# </h3>
# </div>

# %%
fig = px.box(
    df,
    x='Age_Group',
    y='Investment_Portfolio_Usd',
    color='Risk_Category',
    title='Investment Portfolio by Age Group and Risk Category',
    labels={'Age_Group': 'Age Group', 'Investment_Portfolio_Usd': 'Investment Portfolio Value (USD)'}
)

fig.show()

# %% [markdown]
# <div style="background:#fdf2f8;padding:16px;border-radius:10px;border:1px solid #fbcfe8;">
# <b style="color:#be185d;font-size:15px;">💡 Insight</b><br>
# <span style="color:#475569;">
#    <b>* </b>Investment portfolio value tends to increase with age, with Older and Senior investors generally holding larger and more widely distributed portfolios. <br/><b>* </b>Moderate and Low Risk investors show the greatest variation and highest-value outliers, while High Risk portfolios remain comparatively small and consistent across age groups.
# </span></div>

# %% [markdown]
# <div style="
#     margin:30px 0 20px 0;
#     padding:0 0 12px 0;
#     border-bottom:2px solid #2563eb;">
#   <h3 style="
#         margin:0;
#         color:#0f172a;
#         font-size:15px;
#         font-weight:700;
#         line-height:1.5;
#     ">
#         📊 Question 5: How does average saving rate vary jointly across employment status and risk category?
# </h3>
# </div>

# %%
saving_rate_pivot = df.pivot_table(values='Savings_Rate',index='Employment_Status',columns='Risk_Category',observed=True).round(4)

sns.heatmap(saving_rate_pivot,annot=True,fmt='.2f',cmap='viridis')
plt.title('Average Saving Rate by Employment Status and Risk Category',fontweight='bold')
plt.xlabel('Risk Category')
plt.ylabel('Employment Status')
plt.show()

# %% [markdown]
# <div style="background:#fdf2f8;padding:16px;border-radius:10px;border:1px solid #fbcfe8;">
# <b style="color:#be185d;font-size:15px;">💡 Insight</b><br>
# <span style="color:#475569;">
#    <b>* </b>Saving behaviour varies considerably across the combination of employment status and risk category.
#    <br/><b>* </b>Salaried customers show the strongest positive saving rates, particularly in the high-risk category, whereas unemployed and student customers exhibit negative saving rates.<br/><b>* </b> This indicates that employment status plays an important role in differentiating saving behaviour across risk categories.
# </span></div>

# %% [markdown]
# <div style="
#     margin:30px 0 14px 0;
#     padding:15px 20px;
#     background:linear-gradient(90deg,#2563eb 0%,#0f172a 100%);
#     border-radius:12px;
#     color:white;">
#     <h2 style="margin:0;color:white;font-size:18px;">Supporting Analysis</h2>
#     </div>

# %% [markdown]
# <div style="
#     margin:30px 0 20px 0;
#     padding:0 0 12px 0;
#     border-bottom:2px solid #2563eb;">
#   <h3 style="
#         margin:0;
#         color:#0f172a;
#         font-size:15px;
#         font-weight:700;
#         line-height:1.5;
#     ">
#         📊How do Age, Annual Income, Total Debt, Investment Portfolio, and Credit Score relate to one another, and do these relationships differ across Risk Category?
# </h3>
# </div>

# %%
numerical_features = ['Age', 'Annual_Income_Usd', 'Total_Debt_Usd', 'Investment_Portfolio_Usd', 'Credit_Score']

plt.figure(figsize=(20, 15))
sns.pairplot(df, vars=numerical_features, hue='Risk_Category', palette='rocket', diag_kind='kde')
plt.suptitle('Pair Plot of Key Financial Variables by Risk Category', y=1.02)
plt.show()

# %% [markdown]
# <div style="background:#fdf2f8;padding:16px;border-radius:10px;border:1px solid #fbcfe8;">
# <b style="color:#be185d;font-size:15px;">💡 Insight</b><br>
# <span style="color:#475569;">
#    <b>* </b>The pairplot indicates that financial variables show stronger relationships with each other and with Risk Category than Age does.
#     <br/><b>* </b>Annual Income and Credit Score exhibit a strong positive relationship, while Total Debt and Credit Score show a moderate positive association. <br/><b>* </b>Annual Income is also positively related to Investment Portfolio, suggesting that higher-income clients generally hold larger investments. <br/><b>* </b>Age has a weak relationship with Annual Income but shows a moderate positive association with Investment Portfolio. <br/><b>* </b>Across Risk Categories, High Risk clients tend to be associated with lower credit scores, lower income, and smaller investment portfolios, whereas Low Risk clients generally appear at higher levels of these financial indicators. <br/><b>* </b>Moderate Risk clients occupy the largest and most widely distributed group.
# </span></div>

# %% [markdown]
# <div style="
#     margin:30px 0 20px 0;
#     padding:0 0 12px 0;
#     border-bottom:2px solid #2563eb;">
#   <h3 style="
#         margin:0;
#         color:#0f172a;
#         font-size:15px;
#         font-weight:700;
#         line-height:1.5;
#     ">
#         📊How strongly the income,expenses,debt,investment,credit score,session duration,debt income ratio and user satisfaction are related to each other?.
#     </h3>
#
# </div>

# %%
important_cols = [
    'Age',
    'Annual_Income_Usd',
    'Monthly_Expenses_Usd',
    'Total_Debt_Usd',
    'Investment_Portfolio_Usd',
    'Credit_Score',
    'Session_Duration_Min',
    'Debt_Income_Ratio',
    'User_Satisfaction_1_5'
]
plt.figure(figsize=(12, 8))
sns.heatmap(df[important_cols].corr(),annot=True,fmt='.2f',cmap='coolwarm',center=0)
plt.title('Correlation Matrix of Key Financial Variables')
plt.show()

# %% [markdown]
# <div style="background:#fdf2f8;padding:16px;border-radius:10px;border:1px solid #fbcfe8;">
# <b style="color:#be185d;font-size:15px;">💡 Insight</b><br>
# <span style="color:#475569;">
# <b>* </b>The correlation analysis shows several strong positive relationships among the financial variables. <br/><b>* </b>The strongest relationship is between Annual Income and Monthly Expenses (r = 0.89), indicating that users with higher annual income generally have higher monthly expenses. Annual Income also has strong positive correlations with Credit Score (r=0.69) and Total Debt (r=0.66).<br/><b>* </b>Age shows a moderate positive relationship with Investment Portfolio (r = 0.51), while Session Duration has a moderate positive relationship with User Satisfaction(r=0.48).<br/><b>* </b> Overall, the results suggest meaningful associations among income, expenses, debt, credit score, and investment behavior, although these correlations do not establish causation.</span></div>

# %% [markdown]
# <div style="
#     margin:30px 0 14px 0;
#     padding:15px 20px;
#     background:linear-gradient(90deg,#2563eb 0%,#0f172a 100%);
#     border-radius:12px;
#     color:white;">
#     <h2 style="margin:0;color:white;font-size:25px;">Phase 4 – Overall Summary and Final Recommendations</h2>
#     </div>

# %% [markdown]
# <div style="
#     margin:30px 0 14px 0;
#     padding:15px 20px;
#     background:linear-gradient(90deg,#2563eb 0%,#0f172a 100%);
#     border-radius:12px;
#     color:white;">
#     <h2 style="margin:0;color:white;font-size:18px;">Summary of the Analysis</h2>
#     </div>

# %% [markdown]
# ### 1. Client Demographic Profile
#
# The categorical analysis shows that Older clients form the largest age group, with 1,352 clients, followed by Senior clients with 1,213, Young clients with 1,266 and Middle-Aged clients with 1169.
#
# The average client age is approximately 46.8 years, with a median of 46 years. Ages range from 18 to 85, and the middle 50% of clients fall between 30 and 61 years. The age histogram confirms a broad, multi-peaked distribution rather than concentration in a single life stage.
# This indicates that the advisory dataset represents clients across different stages of life and therefore requires more than a single age-based advisory strategy.

# %% [markdown]
# ### 2. Employment Status and Financial Position
# Salaried clients are the largest group, with 1,976 clients, followed by Retired, Self-Employed, Student, and Unemployed clients. Salaried and Retired clients make up about 60% of the client base.
#
# Self-Employed clients have the highest average income (174,437 usd) and debt (274,187 usd), followed by Salaried clients with average income of 149,407 usd and 234,527 usd. Students and Unemployed clients have the lowest income, debt, and monthly expenses. Retired, student and unemployed clients have substantially lower average debt.
#
# Overall, employment status is strongly related to clients' financial capacity, debt, and spending.

# %% [markdown]
# ### 3. Income, Debt, Expenses and Disposable Income
#
# Annual Income, debt, expenses, and disposable income are strongly right-skewed, with most clients in lower-to-moderate ranges and a few with very high values.
#
# Income ranges from approximately 1,000 usd to more than 1.34 million usd whereas annual income has a mean of approximately 108,688 usd, while the median is 90,413 usd, showing the effect of high-income clients.
#
# Income and debt have a positive relationship: higher-income clients generally tend to have higher debt and the skewness analysis further confirms that annual income, investment portfolio, income and debt contain substantial high-value observations. Investment portfolio has the highest skewness and peakedness, while income and debt also demonstrate strong positive skewness.
#
# Overall, the median is more representative than the mean for a typical client.

# %% [markdown]
# ### 4. Investment Portfolio Behaviour
#
# There is a positive relationship between age and investment portfolio size, with a correlation of about 0.51. Older clients generally hold larger investment portfolios, which is consistent with longer periods of wealth accumulation, although age alone does not completely explain portfolio size.
#
# Higher-income clients also tend to have larger investment portfolios, although there is some variation.
#
# Older and Senior clients generally have larger portfolios, while High Risk clients tend to have smaller portfolios. Moderate and Low Risk clients show greater variation and contain the highest-value portfolio observations. The top five portfolio holders have investments of about 3.29–3.81 million usd and are aged 58–63.
#
# Overall, age and income are important factors associated with larger investment portfolios.

# %% [markdown]
# ### 5. Risk Profile
#
# The risk-category analysis shows that Moderate Risk clients dominate the dataset, representing approximately 78% of clients. Low Risk clients account for approximately 21%, while High Risk clients represent only around 0.6%.
# Risk tolerance varies considerably by age group. Young clients have the highest average risk tolerance at approximately 5.39, whereas Middle-Aged clients have the lowest at approximately 2.72. Older clients average approximately 4.38 and Senior clients approximately 3.51.
#
# High Risk clients have higher risk-tolerance scores, with Middle-Aged High Risk clients showing the highest average (8.66). However, this is expected because Risk Category is derived from the risk-tolerance score, and the High Risk group is very small.
#
#
# Marital status, in contrast, has little distinguishing effect on risk tolerance. Even though the violin plots for marital-status groups have very similar distributions and median positions,The Married group has the highest number of observations in all risk categories, mainly because it represents the largest group in the dataset. High Risk cases are very few across all marital-status groups, with no High Risk cases observed among Widowed individuals.

# %% [markdown]
# ### 6. Emergency-Fund Preparedness
#
# Emergency-fund coverage differs across risk categories.
#
# Moderate Risk: approximately 3.4 months
# Low Risk: approximately 3.3 months
# High Risk: approximately 2.5 months
#
# High Risk clients therefore appear to have weaker emergency financial buffers. The wider confidence interval for the High Risk group also indicates greater variability or uncertainty in emergency-fund coverage.
#
# This is an important practical finding because emergency-fund preparedness should be considered alongside investment risk rather than treating investment risk tolerance as the only measure of financial risk.

# %% [markdown]
# ### 7. Communication Preferences
#
# Email is the most preferred communication channel, selected by approximately 30% of clients, followed by App at nearly 26% and Phone at around 20.8%. In-person communication represents approximately 16.2%, while Chat is the least preferred at approximately 6.52%.
#
# Quarterly check-ins are the most common engagement frequency, followed by Biannual and Monthly check-ins. Ad-hoc check-ins are the least common.

# %% [markdown]
# ### 8. Client Satisfaction
#
# Overall client satisfaction is moderate rather than highly positive, with an average score of 2.72 out of 5.
#
# Communication channel alone has little effect on satisfaction, with scores ranging from 2.69 to 2.76, despite Email and App being the most preferred channels.
#
# However, when communication channel and check-in frequency are considered together, satisfaction varies more noticeably. Chat + Monthly has the highest satisfaction score (3.15), while App + Ad-hoc has the lowest (2.44).
#
# Overall, regular client engagement appears to have a stronger influence on satisfaction than communication channel preference alone.

# %% [markdown]
# ### 9. Risk, Employment and Satisfaction
#
# The relationship between risk category and satisfaction is not simply linear.
#
# Average satisfaction across combinations of risk category and employment status ranges from approximately 1.99 to 3.21. Unemployed High Risk clients report the highest satisfaction at 3.21, while Unemployed Low Risk clients report the lowest at 1.99. Self-employed clients show relatively consistent satisfaction across Low and Moderate Risk categories.
#
# This suggests that employment status and client circumstances may interact with risk category when explaining satisfaction, rather than risk category alone determining satisfaction.

# %% [markdown]
# ### 10. Debt-to-Income and Portfolio-to-Income Risk
#
# The analysis identifies important financially vulnerable subgroups.
#
# Unemployed High Risk clients have an exceptionally high portfolio-to-income ratio of approximately 36.9, suggesting that their portfolio value is very large relative to their reported income. This may represent accumulated or pre-existing wealth rather than wealth generated from current earnings.
#
# At the other extreme, Unemployed Low Risk clients have the highest debt-to-income ratio of approximately 5.92, indicating substantial financial pressure relative to income.
#
# These two ratios therefore provide complementary perspectives: portfolio-to-income identifies unusual wealth relative to current income, while debt-to-income highlights financial strain.

# %% [markdown]
# ### 11. Financial Goals
#
# Retirement is the dominant financial goal, with 1,481 clients selecting it, followed by Healthcare with 542 clients. Business Investment is the least common goal with 188 clients.
#
# The target-amount analysis also shows that retirement goals occupy the highest values, with particularly large targets among some marital-status groups. Estate Planning forms another high-value goal category. The analysis indicates that the type of financial goal has a stronger influence on target amount than marital status.

# %% [markdown]
# ### 12. Further Supporting Analysis(Pairplot and Correlation Analysis)
#
# The pairplot provides an overall view of relationships between age, income, debt, portfolio value and credit score across risk categories.
#
# The strongest patterns are seen among the financial variables rather than age. High Risk clients generally appear at lower levels of income, credit score and investment portfolio, while Low Risk clients generally appear at higher levels. Moderate Risk clients form the largest and most widely distributed group.
#
# The correlation matrix provides several particularly important relationships:
#
# - Annual Income ↔ Monthly Expenses: r = 0.89
# - Annual Income ↔ Credit Score: r = 0.69
# - Annual Income ↔ Total Debt: r = 0.66
# - Age ↔ Investment Portfolio: r = 0.51
# - Session Duration ↔ User Satisfaction: r = 0.48
#
# These results indicate strong associations between income and other financial variables, as well as a meaningful relationship between session duration and satisfaction. Importantly, correlation indicates association rather than causation.

# %% [markdown]
# <div style="
#     margin:30px 0 14px 0;
#     padding:15px 20px;
#     background:linear-gradient(90deg,#2563eb 0%,#0f172a 100%);
#     border-radius:12px;
#     color:white;">
#     <h2 style="margin:0;color:white;font-size:18px;">Final Recommendations</h2>
#     </div>

# %% [markdown]
# <div style="
#     background:#ffffff;
#     border:1px solid #e2e8f0;
#     border-left:5px solid #7c3aed;
#     border-radius:10px;
#     padding:18px 20px;
#     margin:12px 0;
#     box-shadow:0 3px 12px rgba(15,23,42,0.06);">
#     <h3 style="margin:0 0 8px 0;color:#0f172a;">1. Introduce various risk-based advisory strategies</h3>
#     <div style="color:#475569;line-height:1.65;">Because, moderate risk clients contribute majority of the customer base, whilst the low and high risk clients did not get any specialised strategies. Because these clients show lower emergency fund coverage and smaller portfolios.</div>
# </div>

# %% [markdown]
# <div style="
#     background:#ffffff;
#     border:1px solid #e2e8f0;
#     border-left:5px solid #7c3aed;
#     border-radius:10px;
#     padding:18px 20px;
#     margin:12px 0;
#     box-shadow:0 3px 12px rgba(15,23,42,0.06);">
#     <h3 style="margin:0 0 8px 0;color:#0f172a;">2. Plan emergency fund providing methods for financially vulnerable clients by checking their demographics and financial position</h3>
#     <div style="color:#475569;line-height:1.65;">Because, high risk clients should be encouraged to increase emergency fund amount before increasing the investment in portfolios.</div>
# </div>

# %% [markdown]
# <div style="
#     background:#ffffff;
#     border:1px solid #e2e8f0;
#     border-left:5px solid #7c3aed;
#     border-radius:10px;
#     padding:18px 20px;
#     margin:12px 0;
#     box-shadow:0 3px 12px rgba(15,23,42,0.06);">
#     <h3 style="margin:0 0 8px 0;color:#0f172a;">3. Strengthen advisor follow-up frequency</h3>
#     <div style="color:#475569;line-height:1.65;">Because, overall client satisfication is moderate. So rather than focusing only on changing communication channels, advisors should consider more structured and frequent follow-ups, particularly for clients currently receiving Annual or Ad-hoc contact. Weekly or any time availability can also be given for clients who require greater support.</div>
# </div>

# %% [markdown]
# <div style="
#     background:#ffffff;
#     border:1px solid #e2e8f0;
#     border-left:5px solid #7c3aed;
#     border-radius:10px;
#     padding:18px 20px;
#     margin:12px 0;
#     box-shadow:0 3px 12px rgba(15,23,42,0.06);">
#     <h3 style="margin:0 0 8px 0;color:#0f172a;">4. Develop goal-based financial planning</h3>
#     <div style="color:#475569;line-height:1.65;">Retirement is the dominant financial goal, followed by Healthcare and other objectives.
#
# Advisory services should therefore provide goal-specific planning frameworks, particularly for retirement and estate planning, with target amounts, time horizons, current portfolio values and financial capacity considered together.</div>
# </div>

# %% [markdown]
# <div style="
#     background:#ffffff;
#     border:1px solid #e2e8f0;
#     border-left:5px solid #7c3aed;
#     border-radius:10px;
#     padding:18px 20px;
#     margin:12px 0;
#     box-shadow:0 3px 12px rgba(15,23,42,0.06);">
#     <h3 style="margin:0 0 8px 0;color:#0f172a;">5. Provide Additional Support to Younger High-Debt Clients</h3>
#     <div style="color:#475569;line-height:1.65;">The highest debt observations are concentrated among relatively younger clients.
#
# Younger clients with high debt should receive greater emphasis on financial stability, debt reduction and cash-flow management before aggressive investment strategies are considered. Along with this, those clients can be notified with messages and alerts about their current situation before get into more trouble.</div>
# </div>

# %% [markdown]
# <div style="
#     background:#ffffff;
#     border:1px solid #e2e8f0;
#     border-left:5px solid #7c3aed;
#     border-radius:10px;
#     padding:18px 20px;
#     margin:12px 0;
#     box-shadow:0 3px 12px rgba(15,23,42,0.06);">
#     <h3 style="margin:0 0 8px 0;color:#0f172a;">6. Use data-driven client segmentation</h3>
#     <div style="color:#475569;line-height:1.65;">Clients can be grouped based on risk, income, employment, debt, and investment behaviour. This can help advisors provide more suitable financial plans to different client groups.</div>
# </div>

# %% [markdown]
# <div style="
#     background:#ffffff;
#     border:1px solid #e2e8f0;
#     border-left:5px solid #7c3aed;
#     border-radius:10px;
#     padding:18px 20px;
#     margin:12px 0;
#     box-shadow:0 3px 12px rgba(15,23,42,0.06);">
#     <h3 style="margin:0 0 8px 0;color:#0f172a;">7. Use flexible communication channels and facility to change if they need.</h3>
#     <div style="color:#475569;line-height:1.65;">Since satisfaction is quite similar across communication channels, clients should be allowed to choose the channel they prefer rather than relying on one specific channel. And also provide facilities to change from one to another if they are not satisfied with the selected channel.</div>
# </div>

# %% [markdown]
# <div style="
#     background:#ffffff;
#     border:1px solid #e2e8f0;
#     border-left:5px solid #7c3aed;
#     border-radius:10px;
#     padding:18px 20px;
#     margin:12px 0;
#     box-shadow:0 3px 12px rgba(15,23,42,0.06);">
#     <h3 style="margin:0 0 8px 0;color:#0f172a;">8. Give age-appropriate investment guidance</h3>
#     <div style="color:#475569;line-height:1.65;">Investment portfolios tend to increase with age. Advisors should consider the client's age and financial stage when designing investment strategies.
# </div>
# </div>

# %% [markdown]
# <div style="
#     background:#ffffff;
#     border:1px solid #e2e8f0;
#     border-left:5px solid #7c3aed;
#     border-radius:10px;
#     padding:18px 20px;
#     margin:12px 0;
#     box-shadow:0 3px 12px rgba(15,23,42,0.06);">
#     <h3 style="margin:0 0 8px 0;color:#0f172a;">9. Review high-value clients and high debit clients carefully</h3>
#     <div style="color:#475569;line-height:1.65;">A small number of clients have extremely high income, debt, or investment portfolios. These clients may require more customized portfolio and risk-management strategies.
#
# </div>
# </div>

# %% [markdown]
# <div style="
#     background:#ffffff;
#     border:1px solid #e2e8f0;
#     border-left:5px solid #7c3aed;
#     border-radius:10px;
#     padding:18px 20px;
#     margin:12px 0;
#     box-shadow:0 3px 12px rgba(15,23,42,0.06);">
#     <h3 style="margin:0 0 8px 0;color:#0f172a;">10. Use client goals for financial planning</h3>
#     <div style="color:#475569;line-height:1.65;">The analysis shows that financial goals have an important relationship with target savings. Advisors should design plans around the client's specific financial goal rather than using the same strategy for everyone.
#
# </div>
# </div>
